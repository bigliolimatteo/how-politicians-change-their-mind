# %% [markdown]
# # Data Cleaning

# %%
#TODO data analysis esplorativa iniziale 
# quanti tweet per politico?
# quanti like per politico?
# quanti retweet?
# ...

# NOTE that here we also have retweets
#for politician in POLITICIANS:
#    print(politician + " " + str(len([tweet for tweet in date_filtered_data[politician] if "RT" not in tweet])))

# %% [markdown]
# ## Importing libraries and data

# %%
import json
import os
import re
import numpy as np
import pandas as pd

from datetime import datetime

import spacy

from sklearn.feature_extraction.text import CountVectorizer
from string import punctuation, digits

from nltk.tokenize import TweetTokenizer
from collections import defaultdict, Counter
from nltk.corpus import stopwords
from string import punctuation
import nltk

from nltk.stem import PorterStemmer, SnowballStemmer

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer

#speller
from autocorrect import Speller

# %%
RELEVANT_FIELDS = ["text", "created_at"]

def read_data(input_directory: str):
    input_data = dict()

    for filename in os.listdir(input_directory):
        if filename.endswith("json"):
            politician_name = filename.split(".")[0]

            file_location = os.path.join(input_directory, filename)
            file = open(file_location, "r")

            tweets = json.load(file)["tweets"]

            filtered_tweets = [{ key: tweet[key] for key in RELEVANT_FIELDS } for tweet in tweets]

            input_data[politician_name] = filtered_tweets
            
        else: 
            raise Exception(f"Input file {filename} has a non supported format.")
    return input_data

# %%
input_data = read_data("data")

# %% [markdown]
# ## Defining cleaning function

# %% [markdown]
# - Remove stopwords
# - Combine tweets that are part1 and part2
# - DONE Remove tweets after a deadline (e.g. the midnight of the election)
# - DONE Remove tweets before a deadline (e.g. max 3 months old) -> this is needed because we need to compare similar timeframes
# - tokenization?
# - stemming / lemmatization

# %%
# TODO do we need to remove digits?
# TODO is it bad to split tweets into subsentences? -> TODO join multiple splitted tweets ((2/2))
# TODO note that there are tweets related to pics that we dont have
# TODO how to manage hashtags and citations (#/@)
# TODO create a pipeline funciton to use in pandas distributed-wise

# %%
# TODO create a pipeline funciton to use in pandas distributed-wise
def date_filter(tweet: dict, start_date = datetime(2022,7,22), end_date = datetime(2022,9,25)):
    created_at = datetime.strptime(tweet['created_at'], "%Y-%m-%dT%H:%M:%S.%fZ")
    return created_at >= start_date and created_at < end_date

def remove_links(tweet: dict):
    return re.sub(r'http\S+', '', tweet["text"])

def is_retweet(tweet: dict):
    return tweet["text"].startswith("RT @")

def preclean_tweet(tweet: dict):
    if date_filter(tweet) and not is_retweet(tweet):
        return remove_links(tweet)  
    else:
        return ""

# %%
POLITICIANS = list(input_data.keys())
filtered_data = {politician: list(filter(None, [preclean_tweet(tweet) for tweet in input_data[politician]])) for politician in POLITICIANS}

# %%
def join_tweets(data, politician): 
    new_list = []

    i = len(data) - 1 
    while i >= 0: #reversed(range(len(data[])))
        if ("1/") in data[i] and ("2/") in data[i-1]:
            n = int(data[i-1][data[i-1].find("2/") + 2])
            new_list.append("".join(data[i-n+1:i+1][::-1]))
            #print("indice merge: ", len(new_list) - 1, i, i-n+1, i+1)
            i -= n
        else: 
            new_list.append(data[i])
            #print("indice: ", i)
            i -= 1
    return new_list

# %%
filtered_joined_data = {politician: join_tweets(filtered_data[politician], politician) for politician in POLITICIANS}

# %%
# Remove punctuation
# Remove stopwords
# Lemmatizer/Stemmer
# Tokenization

# %% [markdown]
# ## NLTK Let's GO!

# %%
nltk.download('stopwords')

ITALIAN_PUNCTUATION = punctuation + "’" # TODO add readibility
# Out:
# [nltk_data] Downloading package stopwords to /Users/billy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Speller
#spell = Speller("it")
#spelled_data = {politician: [spell(tweet) for tweet in filtered_data[politician]] for politician in POLITICIANS}
#%timeit [spell(text) for text in filtered_data["bonino"][0:100]]

# %%
stopw = set(stopwords.words('italian'))
tokenizer = TweetTokenizer()
tokenize = lambda text: [word for word in tokenizer.tokenize(text) #text.lower()
                         if word not in ITALIAN_PUNCTUATION and word not in stopw and not word.startswith('http')]

# %%
tokenized_data = {politician: [tokenize(tweet) for tweet in filtered_joined_data[politician]] for politician in POLITICIANS}

# %%
tokenized_data
# Out:
# {'bonino': [['Oggi',
#    'presenteremo',
#    'federazione',
#    '@Piu_Europa',
#    '@Azione_it',
#    'manifesto',
#    'patto',
#    'repubblicano',
#    'fare',
#    'convergere',
#    'forze',
#    'politiche',
#    'energie',
#    'partire',
#    'possibile',
#    'pronti',
#    'velocemente',
#    'aprire',
#    'confronto',
#    'Mia',
#    'intervista',
#    '@repubblica'],
#   ['Qui', 'leggere'],
#   ['Se',
#    'PD',
#    'pensando',
#    'fare',
#    'campagna',
#    'acquisti',
#    'liberali',
#    'dovrà',
#    'rivedere',
#    'piani',
#    'Oggi',
#    '@Piu_Europa',
#    '@Azione_it',
#    'presentato',
#    'Patto',
#    'repubblicano',
#    'tavole',
#    'legge',
#    'buona',
#    'base',
#    'discussione',
#    "L'intervista",
#    '@Huffington'],
#   ['Leggi', "l'intervista", 'integrale'],
#   ['5',
#    'milioni',
#    'italiani',
#    'soprattutto',
#    'giovani',
#    'rischiano',
#    'poter',
#    'votare',
#    'prossime',
#    'elezioni',
#    'L',
#    'Italia',
#    'pochi',
#    'paesi',
#    'Ue',
#    'consente',
#    'voto',
#    '#fuorisede',
#    'Con',
#    '@riccardomagi',
#    'presentato',
#    'interrogazione',
#    'ministro',
#    '#Lamorgese',
#    '#IOVOTOFUORISEDE',
#    '@Piu_Europa'],
#   [],
#   ['Non',
#    'possiamo',
#    'lamentarci',
#    'scarsa',
#    'partecipazione',
#    'giovani',
#    'vita',
#    'politica',
#    'poi',
#    'permettere',
#    'votare',
#    'vivono',
#    'Per',
#    '@riccardomagi',
#    'presentato',
#    'interrogazione',
#    'Lamorgese',
#    'Leggi',
#    "l'articolo",
#    '@repubblica',
#    'appello',
#    'link',
#    'commenti'],
#   ['Leggi', 'articolo'],
#   ["L'appello", '@Piu_Europa'],
#   ['Contenta',
#    'risultato',
#    'sondaggio',
#    'vede',
#    'federazione',
#    '@Piu_Europa',
#    '@Azione_it',
#    '7',
#    'Significa',
#    'viene',
#    'riconosciuta',
#    'coerenza',
#    'serietà'],
#   ['Molto',
#    'contenta',
#    'soddisfatta',
#    "dell'accordo",
#    'raggiunto',
#    '@Piu_Europa',
#    '@Azione_it',
#    '@pdnetwork',
#    'punta',
#    'programma',
#    'riformista',
#    'improntato',
#    'agenda',
#    'Draghi',
#    'obiettivo',
#    'costruire',
#    'proposta',
#    'governo',
#    'bene',
#    "dell'Italia",
#    'Alternativa',
#    'sovranisti',
#    'populisti'],
#   ["L'accordo",
#    'coalizione',
#    '@Piu_Europa',
#    '@Azione_it',
#    '@pdnetwork',
#    'me',
#    'dettato',
#    'volere',
#    'assumere',
#    'responsabilità',
#    'politica',
#    'regalare',
#    'solo',
#    'voto',
#    'destra',
#    'putiniana',
#    'orbaniana',
#    'portare',
#    'avanti',
#    'agenda',
#    'Draghi',
#    "L'intervista",
#    '@qnazionale'],
#   ['Leggi', "l'intervista"],
#   ['Andando',
#    'divisi',
#    'rischio',
#    'destra',
#    'potesse',
#    'stravincere',
#    'ottendo',
#    'due',
#    'terzi',
#    'Parlamento',
#    'cambiare',
#    'Costituzione',
#    'reale',
#    'E',
#    'dice',
#    'conveniente',
#    'correre',
#    'soli',
#    'vorrei',
#    'sottolineare',
#    'vogliamo',
#    'contribuire',
#    'proseguire',
#    'agenda',
#    'Draghi',
#    'Intervista',
#    '@LaStampa'],
#   ['Leggi', "l'intervista"],
#   ["L'accordo",
#    'politico',
#    'governo',
#    'firmato',
#    'Letta',
#    'prevede',
#    'forte',
#    'spinta',
#    'europeista',
#    'quadro',
#    "dell'agenda",
#    'Draghi',
#    'difendere',
#    'democrazia',
#    'diritti',
#    'posizione',
#    'internazionale',
#    "dell'Italia",
#    '1/2',
#    'Chi',
#    'entrati',
#    'coalizione',
#    'sapeva',
#    'Cosa',
#    'successo',
#    'dopo',
#    'così',
#    'stravolgente',
#    'capisco',
#    'Io',
#    'attengo',
#    'patto',
#    '#Letta',
#    'oggi',
#    'convocata',
#    'direzione',
#    '@Piu_Europa',
#    'discuterà',
#    'deciderà',
#    'Per',
#    'me',
#    'serietà',
#    '2/2',
#    '@repubblica'],
#   ['Leggi', "l'intervista", 'integrale'],
#   ['Non',
#    'mai',
#    'piaciute',
#    'campagne',
#    'elettorali',
#    'qualcuno',
#    'Il',
#    'problema',
#    'dunque',
#    'fascismo',
#    'ieri',
#    'rischia',
#    'tornare',
#    'destra',
#    'oggi',
#    'Ora',
#    'destino',
#    'vogliamo',
#    'Italia',
#    'No',
#    'Noi',
#    'no',
#    'Per',
#    'fondamentale',
#    '#CAMPODEIDIRITTI'],
#   ['Sono',
#    'convinta',
#    'centro',
#    'sinistra',
#    'debba',
#    'ripartire',
#    'campo',
#    'diritti',
#    'battaglie',
#    'libertà',
#    'fatte',
#    'molto',
#    'popolari',
#    'mondo',
#    'politico',
#    'ius',
#    'soli',
#    'legalizzazion',
#    'cannabis',
#    'diritto',
#    'morire',
#    'dignità',
#    'applicazione',
#    '194',
#    'Ieri',
#    '@Tg1Rai'],
#   ['Sono',
#    'felicissima',
#    '@CottarelliCPI',
#    'accettato',
#    "l'offerta",
#    '@Piu_Europa',
#    '@pdnetwork',
#    'essere',
#    'candidato',
#    'comune',
#    'prossime',
#    'elezioni',
#    'È',
#    'dato',
#    'ulteriore',
#    'reale',
#    'serietà',
#    'rispetto',
#    'accordo',
#    'politico',
#    'prosecuzione',
#    'agenda',
#    'Draghi'],
#   ['Serietà',
#    'me',
#    'significa',
#    'tenuta',
#    'coraggio',
#    'quando',
#    'davano',
#    'principi',
#    'fondamentali',
#    'Europa',
#    'diritti',
#    'civili',
#    'libertà',
#    'economiche',
#    'ciascun',
#    'cittadino',
#    'impresa',
#    '@Piu_Europa',
#    'partito',
#    'persone',
#    'lotta',
#    'cambiare',
#    'Italia',
#    'diritto',
#    'volta'],
#   ['Il', '25', 'settembre', '#IoVotoPiùEuropa'],
#   ['Che',
#    'dolore',
#    'perdita',
#    'Piero',
#    'Angela',
#    'La',
#    'stima',
#    'profonda',
#    'legava',
#    'stato',
#    'regalo',
#    'prezioso',
#    'me',
#    'anni',
#    'Grazie',
#    'avere',
#    'reso',
#    'popolare',
#    'scienza',
#    'La',
#    'scomparsa',
#    'impoverisce',
#    'Che',
#    'terra',
#    'lieve',
#    'te',
#    "l'universo",
#    'mai',
#    'fatto',
#    'paura'],
#   ['Per',
#    'Piero',
#    'Angela',
#    'impegno',
#    'civile',
#    'fare',
#    'mestiere',
#    'Rifiutò',
#    'candidarsi',
#    'fianco',
#    'battaglia',
#    'innocenza',
#    'Enzo',
#    'Tortora',
#    'Schierarsi',
#    'quel',
#    'modo',
#    'atto',
#    'coraggio',
#    'andò',
#    'controcorrente',
#    'Il',
#    'ricordo',
#    '@LaStampa'],
#   ['I',
#    'diritti',
#    'punto',
#    'politico',
#    'decisivo',
#    'Dagli',
#    'USA',
#    'Ungheria',
#    'Polonia',
#    'vita',
#    'donne',
#    'persone',
#    'Lgbtiq',
#    'sempre',
#    'difficile',
#    'Da',
#    'liberale',
#    'radicale',
#    'priorità',
#    'resta',
#    'società',
#    'aperta',
#    'temi',
#    'economici',
#    'diritti',
#    'civili',
#    'Progresso',
#    'guarda',
#    'Orban',
#    'Putin',
#    '@Piu_Europa'],
#   ['Leggi', "l'intervista", '@repubblica'],
#   ['Ora', '@Radio24_news'],
#   ['Vorrei',
#    'fare',
#    'appello',
#    'elettori',
#    'elettrici',
#    'votate',
#    'volete',
#    'andate',
#    'votare',
#    'Se',
#    'pensate',
#    '@Piu_Europa',
#    'fatto',
#    'qualcosa',
#    'buono',
#    'votate',
#    'me',
#    'Comunque',
#    'andate',
#    'votare',
#    'Il',
#    'destino',
#    'Paese',
#    'scriverete',
#    'Oggi',
#    '@SkyTG24',
#    'qui',
#    'estratto'],
#   ['Io',
#    'Giorgia',
#    'Emma',
#    'Credo',
#    'possa',
#    'debba',
#    'fare',
#    'campagna',
#    'elettorale',
#    'senza',
#    'insultare',
#    'avversari',
#    'A',
#    'distinguerci',
#    'bastano',
#    'idee',
#    'Il',
#    '25',
#    'settembre',
#    'italiani',
#    'dovranno',
#    'scegliere',
#    'Italia',
#    'vogliono',
#    'vivere',
#    '#iovotopiùeuropa'],
#   ['A',
#    'me',
#    'francamente',
#    'sembra',
#    'letteralmente',
#    'assurdo',
#    'qualcuno',
#    'provi',
#    'rimettere',
#    'discussione',
#    'diritto',
#    'donne',
#    'scegliere',
#    'quando',
#    'diventare',
#    'madri',
#    'Difendi',
#    'diritti',
#    '#iovotopiùeuropa'],
#   ['Sono',
#    'preoccupata',
#    'astensione',
#    '5',
#    'milioni',
#    'fuorisede',
#    'tanti',
#    'giovani',
#    'lavoratori',
#    'potranno',
#    'votare',
#    'È',
#    '2017',
#    'poniamo',
#    'problema',
#    'mai',
#    'momento',
#    'Invito',
#    'andare',
#    'votare',
#    'qualunque',
#    'cosa',
#    'votino',
#    'Se',
#    'poi',
#    'votano',
#    'me',
#    'contenta'],
#   ['Ieri',
#    '@SkyTG24',
#    'elencato',
#    'bonus',
#    'erogati',
#    'Italia',
#    'incidono',
#    'debito',
#    'pubblico'],
#   ['Stasera',
#    'ospite',
#    '@SkyTG24',
#    'trasmissione',
#    'Casa',
#    'Italia',
#    'dedicata',
#    'campagna',
#    'elettorale',
#    'Non',
#    'mancate'],
#   ['Non',
#    'riesco',
#    'capire',
#    'disinvoltura',
#    'altre',
#    'forze',
#    'politiche',
#    'continuino',
#    'parlare',
#    '#scostamentodibilancio',
#    'Dovrebbero',
#    'dire',
#    'verità',
#    'giovani',
#    'debito',
#    'pubblico',
#    'già',
#    'ora',
#    'attesta',
#    '2700',
#    'mld',
#    'pagherete',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera',
#    '#iovotopiùeuropa'],
#   ['Vi',
#    'aspetto',
#    '10.30',
#    'Hotel',
#    'Palatino',
#    "l'apertura",
#    'ufficiale',
#    'campagna',
#    'elettorale',
#    'Insieme',
#    'me',
#    'altri',
#    'candidati',
#    '@Piu_Europa',
#    "l'anteprima",
#    'spot',
#    'elettorale',
#    'Cara',
#    'Italia',
#    '25',
#    'settembre',
#    'resta',
#    'libera',
#    '#iovotopiùeuropa'],
#   ['Per', 'partecipare'],
#   ['Queste',
#    'elezioni',
#    'importanti',
#    'decidono',
#    'qua',
#    'là',
#    'La',
#    'futura',
#    'Italia',
#    'Orban',
#    'Putin',
#    "nell'Ue",
#    'libertà',
#    'civili',
#    'personali',
#    'E',
#    'destino',
#    'dipende',
#    '#ItaliaRestaLibera',
#    '#IoVotoPiuEuropa',
#    '@Piu_Europa'],
#   ['Roma',
#    '25',
#    'resta',
#    'libera',
#    'Domani',
#    'Piazza',
#    'Testaccio',
#    'insieme',
#    '@EnricoLetta',
#    '@bendellavedova',
#    '@riccardomagi',
#    'Segui',
#    'diretta',
#    'pagine',
#    'Facebook',
#    'YouTube',
#    '@Piu_Europa'],
#   ['Altre',
#    '6',
#    'persone',
#    'morte',
#    'sete',
#    'Mediterraneo',
#    "C'è",
#    'propone',
#    'blocchi',
#    'navali',
#    'senza',
#    'serietà',
#    'briciolo',
#    'umanità',
#    'Finché',
#    'possibile',
#    'affrontare',
#    'livello',
#    'europeo',
#    'fenomeno',
#    'vecchio',
#    "l'umanità",
#    'assisteremo',
#    'indicibili',
#    'drammi',
#    'Intervista',
#    '@LaStampa'],
#   ['Leggi', "l'intervista"],
#   ['4',
#    'SÌ',
#    'CON',
#    'UN',
#    'SOLO',
#    'VOTO',
#    'In',
#    'campagna',
#    'elettorale',
#    'parlano',
#    'diritti',
#    'Ma',
#    'solo',
#    '#PiuEuropa',
#    'lotta',
#    'davvero',
#    'averne',
#    'Il',
#    '25',
#    'settembre',
#    'diritti',
#    'cuore',
#    'X',
#    'vale',
#    'Vota',
#    '@Piu_Europa',
#    '#EmmaBonino',
#    'garanzia',
#    'Paese',
#    'finalmente',
#    'libero'],
#   ['La',
#    'protesta',
#    'donne',
#    'Iran',
#    'straordinaria',
#    'Siamo',
#    'parte',
#    'donne',
#    'difesa',
#    'libertà',
#    'diritti',
#    "dell'autodeterminazione",
#    'In',
#    'Iran',
#    'Afghanistan',
#    'ogni',
#    'parte',
#    'mondo',
#    'Non',
#    'ancelle',
#    'donne',
#    'libere',
#    'tutte',
#    '#MahsaAmini'],
#   ['Ci', 'vediamo', 'poco', 'Piazzale', 'Verano'],
#   ['#Putin',
#    'capo',
#    'macchina',
#    'propaganda',
#    'straordinaria',
#    'Continua',
#    'dire',
#    'Ucraina',
#    'attaccato',
#    'Russia',
#    'quindi',
#    'Russia',
#    'deve',
#    'difendersi',
#    'tutte',
#    'balle',
#    'Ma',
#    'Mosca',
#    'tanta',
#    'libertà',
#    'E',
#    'quando',
#    'cittadini',
#    'prendono',
#    '300',
#    'arresti',
#    'oggi',
#    '@TgLa7'],
#   ['6',
#    'milioni',
#    'consumatori',
#    '7',
#    'miliardi',
#    'casse',
#    'Stato',
#    'Vogliamo',
#    'essere',
#    'ragionevoli',
#    'pensare',
#    'davvero',
#    'legalizzare',
#    '#cannabis',
#    'Che',
#    'va',
#    'pari',
#    'passo',
#    'regolarizzazione',
#    'lavoratori',
#    'stranieri',
#    'rimangono',
#    'irregolari',
#    'vanno',
#    'fare',
#    'manovali',
#    'mafia',
#    '@TgLa7'],
#   ['Oggi',
#    'pomeriggio',
#    '@Piu_Europa',
#    'chiuderà',
#    'propria',
#    'campagna',
#    'elettorale',
#    'tour',
#    'bordo',
#    'bus',
#    'Vi',
#    'aspettiamo',
#    'tappa',
#    'conclusiva',
#    'conferenza',
#    'stampa',
#    'davanti',
#    'Galleria',
#    'Nazionale',
#    'Arte',
#    'Moderna',
#    'Contemporanea',
#    'Cara',
#    '#italiarestalibera',
#    '25',
#    'settembre',
#    'vota',
#    'Europa'],
#   ['Nella',
#    'seconda',
#    'tappa',
#    'tour',
#    'chiusura',
#    'campagna',
#    'elettorale',
#    '@Piu_Europa',
#    'incontrato',
#    'comunità',
#    'ucraina',
#    'condannare',
#    'fermezza',
#    'prosecuzione',
#    "l'escalation",
#    'folle',
#    'guerra',
#    'Putin'],
#   ['Tappa',
#    'finale',
#    'tour',
#    'chiusura',
#    'campagna',
#    'elettorale',
#    '@piueuropa',
#    'Per',
#    'tornare',
#    'indietro',
#    'crescere',
#    'progredire',
#    'libertà',
#    'ciascuno',
#    'Italia',
#    'Europa',
#    'prossimo',
#    '25',
#    'settembre',
#    'vota',
#    'Europa',
#    'Cara',
#    '#italiarestalibera'],
#   ['Votare',
#    'Europa',
#    'significa',
#    'schierarsi',
#    'diritti',
#    'libertà',
#    'Europa',
#    'A',
#    'ancora',
#    'dubbi',
#    'scelta',
#    'fare',
#    'dico',
#    "l'unico",
#    'VOTO',
#    'FORTE',
#    'destra',
#    'pericolosa',
#    'illiberale',
#    'voto',
#    'Europa',
#    'centro-sinistra',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera'],
#   ['Domenica',
#    'vota',
#    'scegliere',
#    'futuro',
#    'Paese',
#    'Ti',
#    'chiedo',
#    'immaginare',
#    'Italia',
#    'libera',
#    'Spiega',
#    'voto',
#    'vale',
#    'difendere',
#    'conquistato',
#    'lottare',
#    'averne',
#    'sempre',
#    'Europa',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera'],
#   ['Oggi',
#    'presenteremo',
#    'federazione',
#    '@Piu_Europa',
#    '@Azione_it',
#    'manifesto',
#    'patto',
#    'repubblicano',
#    'fare',
#    'convergere',
#    'forze',
#    'politiche',
#    'energie',
#    'partire',
#    'possibile',
#    'pronti',
#    'velocemente',
#    'aprire',
#    'confronto',
#    'Mia',
#    'intervista',
#    '@repubblica'],
#   ['Qui', 'leggere'],
#   ['Se',
#    'PD',
#    'pensando',
#    'fare',
#    'campagna',
#    'acquisti',
#    'liberali',
#    'dovrà',
#    'rivedere',
#    'piani',
#    'Oggi',
#    '@Piu_Europa',
#    '@Azione_it',
#    'presentato',
#    'Patto',
#    'repubblicano',
#    'tavole',
#    'legge',
#    'buona',
#    'base',
#    'discussione',
#    "L'intervista",
#    '@Huffington'],
#   ['Leggi', "l'intervista", 'integrale'],
#   ['5',
#    'milioni',
#    'italiani',
#    'soprattutto',
#    'giovani',
#    'rischiano',
#    'poter',
#    'votare',
#    'prossime',
#    'elezioni',
#    'L',
#    'Italia',
#    'pochi',
#    'paesi',
#    'Ue',
#    'consente',
#    'voto',
#    '#fuorisede',
#    'Con',
#    '@riccardomagi',
#    'presentato',
#    'interrogazione',
#    'ministro',
#    '#Lamorgese',
#    '#IOVOTOFUORISEDE',
#    '@Piu_Europa'],
#   [],
#   ['Non',
#    'possiamo',
#    'lamentarci',
#    'scarsa',
#    'partecipazione',
#    'giovani',
#    'vita',
#    'politica',
#    'poi',
#    'permettere',
#    'votare',
#    'vivono',
#    'Per',
#    '@riccardomagi',
#    'presentato',
#    'interrogazione',
#    'Lamorgese',
#    'Leggi',
#    "l'articolo",
#    '@repubblica',
#    'appello',
#    'link',
#    'commenti'],
#   ['Leggi', 'articolo'],
#   ["L'appello", '@Piu_Europa'],
#   ['Contenta',
#    'risultato',
#    'sondaggio',
#    'vede',
#    'federazione',
#    '@Piu_Europa',
#    '@Azione_it',
#    '7',
#    'Significa',
#    'viene',
#    'riconosciuta',
#    'coerenza',
#    'serietà'],
#   ['Molto',
#    'contenta',
#    'soddisfatta',
#    "dell'accordo",
#    'raggiunto',
#    '@Piu_Europa',
#    '@Azione_it',
#    '@pdnetwork',
#    'punta',
#    'programma',
#    'riformista',
#    'improntato',
#    'agenda',
#    'Draghi',
#    'obiettivo',
#    'costruire',
#    'proposta',
#    'governo',
#    'bene',
#    "dell'Italia",
#    'Alternativa',
#    'sovranisti',
#    'populisti'],
#   ["L'accordo",
#    'coalizione',
#    '@Piu_Europa',
#    '@Azione_it',
#    '@pdnetwork',
#    'me',
#    'dettato',
#    'volere',
#    'assumere',
#    'responsabilità',
#    'politica',
#    'regalare',
#    'solo',
#    'voto',
#    'destra',
#    'putiniana',
#    'orbaniana',
#    'portare',
#    'avanti',
#    'agenda',
#    'Draghi',
#    "L'intervista",
#    '@qnazionale'],
#   ['Leggi', "l'intervista"],
#   ['Andando',
#    'divisi',
#    'rischio',
#    'destra',
#    'potesse',
#    'stravincere',
#    'ottendo',
#    'due',
#    'terzi',
#    'Parlamento',
#    'cambiare',
#    'Costituzione',
#    'reale',
#    'E',
#    'dice',
#    'conveniente',
#    'correre',
#    'soli',
#    'vorrei',
#    'sottolineare',
#    'vogliamo',
#    'contribuire',
#    'proseguire',
#    'agenda',
#    'Draghi',
#    'Intervista',
#    '@LaStampa'],
#   ['Leggi', "l'intervista"],
#   ["L'accordo",
#    'politico',
#    'governo',
#    'firmato',
#    'Letta',
#    'prevede',
#    'forte',
#    'spinta',
#    'europeista',
#    'quadro',
#    "dell'agenda",
#    'Draghi',
#    'difendere',
#    'democrazia',
#    'diritti',
#    'posizione',
#    'internazionale',
#    "dell'Italia",
#    '1/2',
#    'Chi',
#    'entrati',
#    'coalizione',
#    'sapeva',
#    'Cosa',
#    'successo',
#    'dopo',
#    'così',
#    'stravolgente',
#    'capisco',
#    'Io',
#    'attengo',
#    'patto',
#    '#Letta',
#    'oggi',
#    'convocata',
#    'direzione',
#    '@Piu_Europa',
#    'discuterà',
#    'deciderà',
#    'Per',
#    'me',
#    'serietà',
#    '2/2',
#    '@repubblica'],
#   ['Leggi', "l'intervista", 'integrale'],
#   ['Non',
#    'mai',
#    'piaciute',
#    'campagne',
#    'elettorali',
#    'qualcuno',
#    'Il',
#    'problema',
#    'dunque',
#    'fascismo',
#    'ieri',
#    'rischia',
#    'tornare',
#    'destra',
#    'oggi',
#    'Ora',
#    'destino',
#    'vogliamo',
#    'Italia',
#    'No',
#    'Noi',
#    'no',
#    'Per',
#    'fondamentale',
#    '#CAMPODEIDIRITTI'],
#   ['Sono',
#    'convinta',
#    'centro',
#    'sinistra',
#    'debba',
#    'ripartire',
#    'campo',
#    'diritti',
#    'battaglie',
#    'libertà',
#    'fatte',
#    'molto',
#    'popolari',
#    'mondo',
#    'politico',
#    'ius',
#    'soli',
#    'legalizzazion',
#    'cannabis',
#    'diritto',
#    'morire',
#    'dignità',
#    'applicazione',
#    '194',
#    'Ieri',
#    '@Tg1Rai'],
#   ['Sono',
#    'felicissima',
#    '@CottarelliCPI',
#    'accettato',
#    "l'offerta",
#    '@Piu_Europa',
#    '@pdnetwork',
#    'essere',
#    'candidato',
#    'comune',
#    'prossime',
#    'elezioni',
#    'È',
#    'dato',
#    'ulteriore',
#    'reale',
#    'serietà',
#    'rispetto',
#    'accordo',
#    'politico',
#    'prosecuzione',
#    'agenda',
#    'Draghi'],
#   ['Serietà',
#    'me',
#    'significa',
#    'tenuta',
#    'coraggio',
#    'quando',
#    'davano',
#    'principi',
#    'fondamentali',
#    'Europa',
#    'diritti',
#    'civili',
#    'libertà',
#    'economiche',
#    'ciascun',
#    'cittadino',
#    'impresa',
#    '@Piu_Europa',
#    'partito',
#    'persone',
#    'lotta',
#    'cambiare',
#    'Italia',
#    'diritto',
#    'volta'],
#   ['Il', '25', 'settembre', '#IoVotoPiùEuropa'],
#   ['Che',
#    'dolore',
#    'perdita',
#    'Piero',
#    'Angela',
#    'La',
#    'stima',
#    'profonda',
#    'legava',
#    'stato',
#    'regalo',
#    'prezioso',
#    'me',
#    'anni',
#    'Grazie',
#    'avere',
#    'reso',
#    'popolare',
#    'scienza',
#    'La',
#    'scomparsa',
#    'impoverisce',
#    'Che',
#    'terra',
#    'lieve',
#    'te',
#    "l'universo",
#    'mai',
#    'fatto',
#    'paura'],
#   ['Per',
#    'Piero',
#    'Angela',
#    'impegno',
#    'civile',
#    'fare',
#    'mestiere',
#    'Rifiutò',
#    'candidarsi',
#    'fianco',
#    'battaglia',
#    'innocenza',
#    'Enzo',
#    'Tortora',
#    'Schierarsi',
#    'quel',
#    'modo',
#    'atto',
#    'coraggio',
#    'andò',
#    'controcorrente',
#    'Il',
#    'ricordo',
#    '@LaStampa'],
#   ['I',
#    'diritti',
#    'punto',
#    'politico',
#    'decisivo',
#    'Dagli',
#    'USA',
#    'Ungheria',
#    'Polonia',
#    'vita',
#    'donne',
#    'persone',
#    'Lgbtiq',
#    'sempre',
#    'difficile',
#    'Da',
#    'liberale',
#    'radicale',
#    'priorità',
#    'resta',
#    'società',
#    'aperta',
#    'temi',
#    'economici',
#    'diritti',
#    'civili',
#    'Progresso',
#    'guarda',
#    'Orban',
#    'Putin',
#    '@Piu_Europa'],
#   ['Leggi', "l'intervista", '@repubblica'],
#   ['Ora', '@Radio24_news'],
#   ['Vorrei',
#    'fare',
#    'appello',
#    'elettori',
#    'elettrici',
#    'votate',
#    'volete',
#    'andate',
#    'votare',
#    'Se',
#    'pensate',
#    '@Piu_Europa',
#    'fatto',
#    'qualcosa',
#    'buono',
#    'votate',
#    'me',
#    'Comunque',
#    'andate',
#    'votare',
#    'Il',
#    'destino',
#    'Paese',
#    'scriverete',
#    'Oggi',
#    '@SkyTG24',
#    'qui',
#    'estratto'],
#   ['Io',
#    'Giorgia',
#    'Emma',
#    'Credo',
#    'possa',
#    'debba',
#    'fare',
#    'campagna',
#    'elettorale',
#    'senza',
#    'insultare',
#    'avversari',
#    'A',
#    'distinguerci',
#    'bastano',
#    'idee',
#    'Il',
#    '25',
#    'settembre',
#    'italiani',
#    'dovranno',
#    'scegliere',
#    'Italia',
#    'vogliono',
#    'vivere',
#    '#iovotopiùeuropa'],
#   ['A',
#    'me',
#    'francamente',
#    'sembra',
#    'letteralmente',
#    'assurdo',
#    'qualcuno',
#    'provi',
#    'rimettere',
#    'discussione',
#    'diritto',
#    'donne',
#    'scegliere',
#    'quando',
#    'diventare',
#    'madri',
#    'Difendi',
#    'diritti',
#    '#iovotopiùeuropa'],
#   ['Sono',
#    'preoccupata',
#    'astensione',
#    '5',
#    'milioni',
#    'fuorisede',
#    'tanti',
#    'giovani',
#    'lavoratori',
#    'potranno',
#    'votare',
#    'È',
#    '2017',
#    'poniamo',
#    'problema',
#    'mai',
#    'momento',
#    'Invito',
#    'andare',
#    'votare',
#    'qualunque',
#    'cosa',
#    'votino',
#    'Se',
#    'poi',
#    'votano',
#    'me',
#    'contenta'],
#   ['Ieri',
#    '@SkyTG24',
#    'elencato',
#    'bonus',
#    'erogati',
#    'Italia',
#    'incidono',
#    'debito',
#    'pubblico'],
#   ['Stasera',
#    'ospite',
#    '@SkyTG24',
#    'trasmissione',
#    'Casa',
#    'Italia',
#    'dedicata',
#    'campagna',
#    'elettorale',
#    'Non',
#    'mancate'],
#   ['Non',
#    'riesco',
#    'capire',
#    'disinvoltura',
#    'altre',
#    'forze',
#    'politiche',
#    'continuino',
#    'parlare',
#    '#scostamentodibilancio',
#    'Dovrebbero',
#    'dire',
#    'verità',
#    'giovani',
#    'debito',
#    'pubblico',
#    'già',
#    'ora',
#    'attesta',
#    '2700',
#    'mld',
#    'pagherete',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera',
#    '#iovotopiùeuropa'],
#   ['Vi',
#    'aspetto',
#    '10.30',
#    'Hotel',
#    'Palatino',
#    "l'apertura",
#    'ufficiale',
#    'campagna',
#    'elettorale',
#    'Insieme',
#    'me',
#    'altri',
#    'candidati',
#    '@Piu_Europa',
#    "l'anteprima",
#    'spot',
#    'elettorale',
#    'Cara',
#    'Italia',
#    '25',
#    'settembre',
#    'resta',
#    'libera',
#    '#iovotopiùeuropa'],
#   ['Per', 'partecipare'],
#   ['Queste',
#    'elezioni',
#    'importanti',
#    'decidono',
#    'qua',
#    'là',
#    'La',
#    'futura',
#    'Italia',
#    'Orban',
#    'Putin',
#    "nell'Ue",
#    'libertà',
#    'civili',
#    'personali',
#    'E',
#    'destino',
#    'dipende',
#    '#ItaliaRestaLibera',
#    '#IoVotoPiuEuropa',
#    '@Piu_Europa'],
#   ['Roma',
#    '25',
#    'resta',
#    'libera',
#    'Domani',
#    'Piazza',
#    'Testaccio',
#    'insieme',
#    '@EnricoLetta',
#    '@bendellavedova',
#    '@riccardomagi',
#    'Segui',
#    'diretta',
#    'pagine',
#    'Facebook',
#    'YouTube',
#    '@Piu_Europa'],
#   ['Altre',
#    '6',
#    'persone',
#    'morte',
#    'sete',
#    'Mediterraneo',
#    "C'è",
#    'propone',
#    'blocchi',
#    'navali',
#    'senza',
#    'serietà',
#    'briciolo',
#    'umanità',
#    'Finché',
#    'possibile',
#    'affrontare',
#    'livello',
#    'europeo',
#    'fenomeno',
#    'vecchio',
#    "l'umanità",
#    'assisteremo',
#    'indicibili',
#    'drammi',
#    'Intervista',
#    '@LaStampa'],
#   ['Leggi', "l'intervista"],
#   ['4',
#    'SÌ',
#    'CON',
#    'UN',
#    'SOLO',
#    'VOTO',
#    'In',
#    'campagna',
#    'elettorale',
#    'parlano',
#    'diritti',
#    'Ma',
#    'solo',
#    '#PiuEuropa',
#    'lotta',
#    'davvero',
#    'averne',
#    'Il',
#    '25',
#    'settembre',
#    'diritti',
#    'cuore',
#    'X',
#    'vale',
#    'Vota',
#    '@Piu_Europa',
#    '#EmmaBonino',
#    'garanzia',
#    'Paese',
#    'finalmente',
#    'libero'],
#   ['La',
#    'protesta',
#    'donne',
#    'Iran',
#    'straordinaria',
#    'Siamo',
#    'parte',
#    'donne',
#    'difesa',
#    'libertà',
#    'diritti',
#    "dell'autodeterminazione",
#    'In',
#    'Iran',
#    'Afghanistan',
#    'ogni',
#    'parte',
#    'mondo',
#    'Non',
#    'ancelle',
#    'donne',
#    'libere',
#    'tutte',
#    '#MahsaAmini'],
#   ['Ci', 'vediamo', 'poco', 'Piazzale', 'Verano'],
#   ['#Putin',
#    'capo',
#    'macchina',
#    'propaganda',
#    'straordinaria',
#    'Continua',
#    'dire',
#    'Ucraina',
#    'attaccato',
#    'Russia',
#    'quindi',
#    'Russia',
#    'deve',
#    'difendersi',
#    'tutte',
#    'balle',
#    'Ma',
#    'Mosca',
#    'tanta',
#    'libertà',
#    'E',
#    'quando',
#    'cittadini',
#    'prendono',
#    '300',
#    'arresti',
#    'oggi',
#    '@TgLa7'],
#   ['6',
#    'milioni',
#    'consumatori',
#    '7',
#    'miliardi',
#    'casse',
#    'Stato',
#    'Vogliamo',
#    'essere',
#    'ragionevoli',
#    'pensare',
#    'davvero',
#    'legalizzare',
#    '#cannabis',
#    'Che',
#    'va',
#    'pari',
#    'passo',
#    'regolarizzazione',
#    'lavoratori',
#    'stranieri',
#    'rimangono',
#    'irregolari',
#    'vanno',
#    'fare',
#    'manovali',
#    'mafia',
#    '@TgLa7'],
#   ['Oggi',
#    'pomeriggio',
#    '@Piu_Europa',
#    'chiuderà',
#    'propria',
#    'campagna',
#    'elettorale',
#    'tour',
#    'bordo',
#    'bus',
#    'Vi',
#    'aspettiamo',
#    'tappa',
#    'conclusiva',
#    'conferenza',
#    'stampa',
#    'davanti',
#    'Galleria',
#    'Nazionale',
#    'Arte',
#    'Moderna',
#    'Contemporanea',
#    'Cara',
#    '#italiarestalibera',
#    '25',
#    'settembre',
#    'vota',
#    'Europa'],
#   ['Nella',
#    'seconda',
#    'tappa',
#    'tour',
#    'chiusura',
#    'campagna',
#    'elettorale',
#    '@Piu_Europa',
#    'incontrato',
#    'comunità',
#    'ucraina',
#    'condannare',
#    'fermezza',
#    'prosecuzione',
#    "l'escalation",
#    'folle',
#    'guerra',
#    'Putin'],
#   ['Tappa',
#    'finale',
#    'tour',
#    'chiusura',
#    'campagna',
#    'elettorale',
#    '@piueuropa',
#    'Per',
#    'tornare',
#    'indietro',
#    'crescere',
#    'progredire',
#    'libertà',
#    'ciascuno',
#    'Italia',
#    'Europa',
#    'prossimo',
#    '25',
#    'settembre',
#    'vota',
#    'Europa',
#    'Cara',
#    '#italiarestalibera'],
#   ['Votare',
#    'Europa',
#    'significa',
#    'schierarsi',
#    'diritti',
#    'libertà',
#    'Europa',
#    'A',
#    'ancora',
#    'dubbi',
#    'scelta',
#    'fare',
#    'dico',
#    "l'unico",
#    'VOTO',
#    'FORTE',
#    'destra',
#    'pericolosa',
#    'illiberale',
#    'voto',
#    'Europa',
#    'centro-sinistra',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera'],
#   ['Domenica',
#    'vota',
#    'scegliere',
#    'futuro',
#    'Paese',
#    'Ti',
#    'chiedo',
#    'immaginare',
#    'Italia',
#    'libera',
#    'Spiega',
#    'voto',
#    'vale',
#    'difendere',
#    'conquistato',
#    'lottare',
#    'averne',
#    'sempre',
#    'Europa',
#    'Cara',
#    'Italia',
#    '25',
#    'resta',
#    'libera']],
#  'dimaio': [['L',
#    '#export',
#    'italiano',
#    'ferma',
#    'Dopo',
#    'boom',
#    "dell'anno",
#    'scorso',
#    'cifra',
#    'record',
#    '516',
#    'miliardi',
#    'euro',
#    'esportazioni',
#    '#MadeinItaly',
#    'aumentano',
#    'ancora',
#    'nonostante',
#    'crisi',
#    'globale'],
#   ['Solidarietà',
#    'tutta',
#    'redazione',
#    'de',
#    '@LaStampa',
#    'direttore',
#    '@MassimGiannini',
#    'vile',
#    'attacco',
#    'vandalico',
#    'subito',
#    'Ferma',
#    'condanna',
#    'gesti',
#    'inqualificabili',
#    'pieno',
#    'sostegno',
#    "all'attività",
#    'informazione',
#    'servizio',
#    'cittadini'],
#   ['42',
#    'anni',
#    '#stragedibologna',
#    'Vite',
#    'innocenti',
#    'tragicamente',
#    'spezzate',
#    'giovanissime',
#    'Una',
#    'preghiera',
#    "l'impegno",
#    'ricerca',
#    'verità',
#    'lotta',
#    'terrorismo',
#    'sempre',
#    'incisive'],
#   ['Carlo',
#    'sollievo',
#    'reciproco',
#    'Continua',
#    'spargere',
#    'odio',
#    'rancore',
#    'cosa',
#    'viene',
#    'bene',
#    'Hai',
#    'scelto',
#    'schierarti',
#    'parte',
#    'fatto',
#    'cadere',
#    'governo',
#    'Draghi',
#    'prendiamo',
#    'atto',
#    'Ma',
#    'basta',
#    'lezioni',
#    'coerenza',
#    'P',
#    'S',
#    'saluta',
#    'Renzi'],
#   ['Attenti', 'coalizione', 'sfascia-conti'],
#   ['I',
#    'leader',
#    'coalizione',
#    '#sfasciaconti',
#    'rispondono',
#    'proposta',
#    'tetto',
#    'massimo',
#    'prezzo',
#    'gas',
#    'intanto',
#    'italiani',
#    'pagano',
#    'bollette',
#    'insostenibili',
#    'Poco',
#    'fa',
#    'stato',
#    'ospite',
#    '#ZonaBianca',
#    'seguitemi'],
#   ['Giorgia',
#    'Meloni',
#    'insulta',
#    'dico',
#    'verità',
#    'programmi',
#    'coalizione',
#    '#sfasciaconti',
#    'destra',
#    'mettono',
#    'rischio',
#    'libertà',
#    'Paese',
#    'risparmi',
#    'italiani',
#    'Le',
#    'rispondo',
#    'video',
#    'collegatevi'],
#   ['Oggi',
#    'intervista',
#    '#SpecialeElezioni',
#    '@RadioR101',
#    'La',
#    'trovate',
#    'qui',
#    '👇🏻'],
#   ['Ridurre',
#    'bollette',
#    'famiglie',
#    'imprese',
#    'tetto',
#    'massimo',
#    'europeo',
#    'prezzo',
#    'gas',
#    'priorità',
#    'quali',
#    '@impegno_civico',
#    'continua',
#    'lavorare',
#    'Ecco',
#    'intervista',
#    '#agorarai',
#    'seguitemi'],
#   ['La',
#    'proposta',
#    '@impegno_civico',
#    'decreto',
#    'taglia',
#    'bollette',
#    'approvare',
#    'subito',
#    'consenta',
#    'tutte',
#    'imprese',
#    'fino',
#    'fine',
#    "dell'anno",
#    'vedersi',
#    'pagato',
#    'Stato',
#    '80',
#    'bollette',
#    'Leggi',
#    'intervista',
#    '@LaStampa',
#    '👇🏻'],
#   ['Dal', 'trio', '#sfasciaconti', 'destra', 'scenario', 'inquietante'],
#   ['Decreto',
#    '#tagliabollette',
#    'imprese',
#    'tetto',
#    'massimo',
#    'europeo',
#    'prezzo',
#    'gas',
#    '@impegno_civico',
#    'può',
#    'trio',
#    '#sfasciaconti',
#    'destra',
#    "l'Italia",
#    'va',
#    'default',
#    'Ecco',
#    'intervista',
#    '@SkyTG24'],
#   ['Il',
#    'decreto',
#    '#tagliabollette',
#    'prima',
#    'cosa',
#    'proporremo',
#    'nuova',
#    'legislatura'],
#   ['Con',
#    'Decreto',
#    '#tagliabollette',
#    'riduciamo',
#    '80',
#    'costo',
#    "dell'energia",
#    'imprese',
#    'qui',
#    'fine',
#    'anno',
#    'Il',
#    'intervento',
#    '#DrittoeRovescio'],
#   ['Qualcuno', 'visto', 'Salvini', '🤔', '➡', '️'],
#   ['Al',
#    '#G7',
#    'Finanze',
#    'passo',
#    'avanti',
#    'decisivo',
#    'tetto',
#    'prezzo',
#    'petrolio',
#    'russo',
#    'Ora',
#    'mostrare',
#    'stessa',
#    'determinazione',
#    'Ue',
#    'ottenere',
#    'tetto',
#    'massimo',
#    'prezzo',
#    'gas',
#    'Basta',
#    'speculazioni',
#    'bisogna',
#    'sostenere',
#    'famiglie',
#    'imprese'],
#   ['#tagliabollette'],
#   ['Le',
#    'proposte',
#    '@impegno_civico',
#    'favore',
#    'famiglie',
#    'imprese',
#    'decreto',
#    '#TagliaBollette',
#    'tetto',
#    'massimo',
#    'prezzo',
#    'gas',
#    'tutte',
#    'Poco',
#    'fa',
#    '#inonda',
#    '@La7tv',
#    'Seguitemi'],
#   ['Ci',
#    'vediamo',
#    '15:45',
#    '#mezzorainpiu',
#    'cose',
#    'importanti',
#    'dirvi',
#    'Potete',
#    'seguire',
#    'diretta',
#    '@RaiTre',
#    'streaming'],
#   ['L',
#    '#export',
#    'italiano',
#    'trionfa',
#    'ancora',
#    'grazie',
#    '#PattoExport',
#    'creato',
#    'sempre',
#    'creduto'],
#   ['My',
#    'warmest',
#    'congratulations',
#    '@JamesCleverly',
#    'for',
#    'your',
#    'new',
#    'responsibility',
#    'as',
#    'UK',
#    'Foreign',
#    'Secretary',
#    'Our',
#    'countries',
#    '🇮',
#    '🇹',
#    '🇬',
#    '🇧',
#    'will',
#    'continue',
#    'to',
#    'work',
#    'towards',
#    'an',
#    'even',
#    'closer',
#    'and',
#    'stronger',
#    'partnership'],
#   ['@CarloCalenda',
#    'Carlo',
#    'essere',
#    'sempre',
#    'superficiale',
#    'polemico',
#    'cose',
#    'Basta',
#    'ascoltare',
#    'parole',
#    'vedere',
#    'errore',
#    'fatto',
#    'trascritto',
#    'maniera',
#    'errata',
#    'parole'],
#   ['I',
#    'am',
#    'deeply',
#    'saddened',
#    'by',
#    'the',
#    'news',
#    'of',
#    'the',
#    'passing',
#    'of',
#    'Queen',
#    'Elizabeth',
#    'II',
#    'She',
#    'embodied',
#    'the',
#    'British',
#    'spirit',
#    'inspiring',
#    'generations',
#    'over',
#    'the',
#    'world',
#    'I',
#    'offer',
#    "Italy's",
#    'deepest',
#    'and',
#    'heartfelt',
#    'condolences',
#    'to',
#    'the',
#    '@RoyalFamily',
#    'and',
#    'the',
#    'British',
#    'people'],
#   ['Oggi',
#    '#lariachetira',
#    'proposte',
#    '@impegno_civico',
#    '#MutuoZAC',
#    'Zero',
#    'Anticipo',
#    'Casa',
#    'under',
#    '40',
#    'decreto',
#    '#TagliaBollette',
#    'tetto',
#    'massimo',
#    'prezzo',
#    'gas',
#    'Ecco',
#    'intervista',
#    'seguitemi'],
#   ['Con',
#    'decreto',
#    'Taglia',
#    'Bollette',
#    'proposto',
#    '@impegno_civico',
#    'Stato',
#    'paga',
#    'fino',
#    'fine',
#    'anno',
#    '80',
#    'bollette',
#    'imprese',
#    'famiglie',
#    'Calcola',
#    'pagheresti',
#    '#TagliaBollette',
#    '👇🏻'],
#   ['In', 'diretta', '#Metropolis', 'seguitemi'],
#   ['A',
#    '@NapoliToday',
#    'parlare',
#    'programma',
#    '@impegno_civico',
#    'porta',
#    'avanti',
#    'E',
#    'poi',
#    'massima',
#    'attenzione',
#    'trio',
#    '#sfasciaconti',
#    'destra',
#    'pericolo',
#    'Italia',
#    '#Sud',
#    'particolare',
#    'Qui',
#    'intervista',
#    'video'],
#   ['Questa', 'mattina', '#omnibusla7', 'seguitemi', '💪🏻'],
#   ['La', 'intervista', '#tagadala7', '👇🏻'],
#   ['Poco',
#    'fa',
#    'Filo',
#    'Diretto',
#    'Verso',
#    'Voto',
#    '#Rainews24',
#    'proposte',
#    '@impegno_civico',
#    'imprese',
#    'famiglie',
#    'Seguitemi',
#    '💪🏻'],
#   ['@CarloCalenda',
#    '@pdnetwork',
#    'Carlo',
#    'scendi',
#    'piedistallo',
#    'fatti',
#    'bagno',
#    'umiltà',
#    'smettila',
#    'fare',
#    'maestro',
#    'coerenza',
#    'Tu',
#    'protetto',
#    'Renzi',
#    'Un',
#    'voto',
#    'Calenda',
#    'voto',
#    'Renzi',
#    '…',
#    'sì',
#    'Renzi'],
#   ['Serve',
#    'decreto',
#    '#TagliaBollette',
#    'affinché',
#    'Stato',
#    'paghi',
#    '80',
#    'bollette',
#    'imprese',
#    'famiglie',
#    'In',
#    'diretta',
#    '#StaseraItalia',
#    'seguitemi'],
#   ['Massima',
#    'solidarietà',
#    'famiglie',
#    'vittime',
#    'dispersi',
#    '#Marche',
#    'comunità',
#    'colpite',
#    'catastrofe',
#    'Il',
#    'intervento',
#    '#agorarai'],
#   ['Stamattina',
#    'ospite',
#    '@rtl1025',
#    'potete',
#    'riascoltare',
#    'intervista',
#    'qui'],
#   ['@EnricoLetta',
#    'sempre',
#    'squadra',
#    'insieme',
#    'uniti',
#    'possibile',
#    'rimonta',
#    'sorprendente',
#    'La',
#    'destra',
#    'vinto',
#    'Con',
#    'Meloni',
#    'Berlusconi',
#    'Salvini',
#    'rischia',
#    'catastrofe',
#    'economica',
#    'Il',
#    'voto',
#    'utile',
#    'esiste',
#    'coalizione',
#    'progressista',
#    'Ora',
#    'colpo',
#    'reni',
#    'finale',
#    '💪🏻'],
#   ['In', 'diretta', '#ZonaBianca', 'seguitemi', '💪🏻'],
#   ['Ora', 'diretta', '@1giornodapecora', '@Radio1Rai', 'seguitemi', '#ugdp'],
#   ['In',
#    'diretta',
#    '#pomeriggio5',
#    'Barbara',
#    'd',
#    'Urso',
#    'parlarvi',
#    'proposte',
#    '@impegno_civico',
#    'Seguitemi',
#    '😀'],
#   ['Un',
#    'voto',
#    '@impegno_civico',
#    'voto',
#    'difendere',
#    '#RedditodiCittadinanza',
#    'destra',
#    'vuole',
#    'abolire',
#    'decreto',
#    '#TagliaBollette',
#    'Stato',
#    'paga',
#    '80',
#    'bollette',
#    'imprese',
#    'famiglie',
#    'In',
#    'diretta',
#    '#OggièUnAltroGiorno'],
#   ['Un',
#    'voto',
#    '@impegno_civico',
#    'voto',
#    'difesa',
#    '#RedditodiCittadinanza',
#    'decreto',
#    '#TagliaBollette',
#    'Oggi',
#    '#Mattino5',
#    'seguitemi'],
#   ['Con',
#    '@impegno_civico',
#    'sviluppato',
#    'programma',
#    'dettagliato',
#    'realizzabile',
#    'seguitemi',
#    'parlo',
#    '#Tg1Mattina',
#    '🐝']],
#  'salvini': [['Che',
#    'dite',
#    'gentiluomo',
#    'centri',
#    'sociali',
#    'minaccia',
#    'insulta',
#    'invita',
#    'aperitivo',
#    '🤣',
#    '25',
#    'settembre',
#    'parola',
#    'Italiani'],
#   ['Solidarietà',
#    'impegno',
#    'vincere',
#    'elezioni',
#    'tornare',
#    'controllare',
#    'immigrazione',
#    'confini'],
#   ['Buone',
#    'notizie',
#    'fronte',
#    'guerra',
#    'accordo',
#    'fra',
#    'Ucraina',
#    'Russia',
#    'sbloccare',
#    'navi',
#    'porti',
#    'bloccati',
#    'oltre',
#    '25',
#    'milioni',
#    'tonnellate',
#    'grano',
#    'potranno',
#    'raggiungere',
#    'resto',
#    'mondo'],
#   ['Gratitudine',
#    'Turchia',
#    'ospitato',
#    'incontri',
#    'promosso',
#    'accordo',
#    'firmato',
#    'Onu',
#    'Speriamo',
#    'primo',
#    'importante',
#    'segnale',
#    'ritorno',
#    'dialogo',
#    'dopo',
#    'troppi',
#    'mesi',
#    'morte',
#    'guerra'],
#   ['#Diana',
#    'piccolo',
#    'angelo',
#    '18',
#    'mesi',
#    'volato',
#    'cielo',
#    'troppo',
#    'presto',
#    'abbandonata',
#    'casa',
#    'giorni',
#    '“',
#    'madre',
#    '”',
#    'snaturata',
#    'morta',
#    'stenti',
#    'Che',
#    'Cielo',
#    'accolga',
#    'possa',
#    'finalmente',
#    'sorridere',
#    'giocare',
#    'piccola'],
#   ['Il',
#    'prossimo',
#    'premier',
#    'Finalmente',
#    'sceglieranno',
#    'Italiani',
#    'prenderà',
#    'voto',
#    'onore',
#    'onere',
#    'indicare',
#    'nome'],
#   ['Vi',
#    'do',
#    'appuntamento',
#    'sera',
#    'festa',
#    'Lega',
#    'Domodossola',
#    'VB',
#    'momento',
#    'compagnia',
#    'sorrisi',
#    'voglia',
#    'ripartire',
#    '💪'],
#   ['Il',
#    '25',
#    'settembre',
#    'avvicina',
#    'sinistra',
#    'terrorizzati',
#    'voto',
#    'finalmente',
#    'parola',
#    'torna',
#    'Italiani',
#    '🇮',
#    '🇹'],
#   ['Festa',
#    'Lega',
#    'Domodossola',
#    'VB',
#    '):',
#    'presenza',
#    'energia',
#    'entusiasmo',
#    'mille',
#    '😊',
#    'A',
#    'sinistra',
#    'litigano',
#    'andiamo',
#    'avanti',
#    'sorriso',
#    'coraggio',
#    'vuole',
#    'costruire',
#    'Futuro',
#    'migliore',
#    'Forza',
#    'Amici',
#    '❤',
#    '️'],
#   ['Clandestini',
#    'finti',
#    'profughi',
#    'spacciatori',
#    'stupratori',
#    '25',
#    'settembre',
#    'casa'],
#   ['411',
#    'clandestini',
#    'sbarcati',
#    'poche',
#    'ore',
#    'Lampedusa',
#    'emergenza',
#    'Il',
#    '25',
#    'settembre',
#    'italiani',
#    'potranno',
#    'finalmente',
#    'scegliere',
#    'cambiare',
#    'tornano',
#    'sicurezza',
#    'coraggio',
#    'controllo',
#    'confini'],
#   ['Una',
#    'preghiera',
#    'ricordo',
#    'Vittorio',
#    'De',
#    'Scalzi',
#    'grandissimo',
#    'cantautore',
#    'genovese',
#    'Un',
#    'abbraccio',
#    'famiglia',
#    'dolore'],
#   ['Insulti',
#    'nervosismo',
#    'Lega',
#    'vuole',
#    'fermare',
#    'Legge',
#    'Fornero',
#    'sinistra',
#    'mettano',
#    'cuore',
#    'pace',
#    '25',
#    'settembre',
#    'decideranno',
#    'solo',
#    'soltanto',
#    'italiani',
#    'voto'],
#   ['Più',
#    'morti',
#    'sbarchi',
#    'soldi',
#    'trafficanti',
#    'significa',
#    'sofferenze',
#    'Bisogna',
#    'cambiare',
#    'può',
#    'cambiare',
#    'Col',
#    'voto',
#    'Italiani',
#    '25',
#    'settembre',
#    'tornano',
#    'sicurezza',
#    'coraggio'],
#   ['Addio',
#    'Franco',
#    'leghista',
#    'prima',
#    'ora',
#    'persona',
#    'perbene',
#    'Te',
#    'andato',
#    'improvviso',
#    'amata',
#    'montagna',
#    'proteggi',
#    'lassù',
#    'gente',
#    'Una',
#    'preghiera',
#    'abbraccio',
#    'famiglia'],
#   ['E',
#    'SE',
#    'FOSSI',
#    'TU',
#    'QUEL',
#    'RAGAZZO',
#    'Napoli',
#    'ragazzo',
#    'rapinato',
#    '2',
#    'giovani',
#    'africani',
#    'immagini',
#    'dimostrano',
#    'città',
#    'insicure',
#    'ministro',
#    "all'altezza",
#    'Basta',
#    'Con',
#    'voto',
#    '25',
#    'settembre',
#    'Paese',
#    'deve',
#    'tornare',
#    'essere',
#    'sicuro',
#    'basta',
#    'buonismo',
#    'sinistra'],
#   ['Grandissimo',
#    'Massimo',
#    '#Stano',
#    'Il',
#    'campione',
#    'olimpico',
#    'oro',
#    'mondiale',
#    '35',
#    'km',
#    'marcia',
#    'Eugene',
#    'Orgoglio',
#    'italiano',
#    '🇮',
#    '🇹',
#    '👏🏻',
#    '#WorldAthleticsChamps',
#    '#atletica'],
#   ['Repubblica',
#    'panico',
#    'pre-elezioni',
#    'adesso',
#    'Lega',
#    'addirittura',
#    'OSCURANTISTA',
#    '…',
#    '🤣'],
#   ['Ecco',
#    'finti',
#    'democratici',
#    'azione',
#    'Marano',
#    'Vicentino',
#    'Si',
#    'professano',
#    'paladini',
#    'Democrazia',
#    'permetti',
#    'pensare',
#    'diversamente',
#    'finisci',
#    'testa',
#    'giù',
#    '...',
#    'Non',
#    'fate',
#    'paura',
#    'preparate',
#    'Maalox',
#    '25',
#    'settembre',
#    '😊'],
#   ['Ho',
#    'appena',
#    'sentito',
#    'vicesindaco',
#    'Lampedusa',
#    'situazione',
#    'allarmante',
#    'arrivi',
#    'ormai',
#    'fuori',
#    'controllo',
#    'hotspot',
#    'pieno',
#    'oltre',
#    'limiti',
#    'umanità',
#    'Arriverò',
#    'Isola',
#    '4',
#    '5',
#    'agosto',
#    'portare',
#    'idee',
#    'soluzioni',
#    'già',
#    'messo',
#    'pratica',
#    'successo'],
#   ['Amici',
#    'Lampedusani',
#    'dopo',
#    'fallimento',
#    'lavoro',
#    'Lamorgese',
#    'prossimo',
#    'ministro',
#    'bloccherà',
#    'arrivi',
#    'ormai',
#    'ingestibili',
#    'proprio',
#    'fatto',
#    'Lega',
#    'quando',
#    'Viminale'],
#   ['Proposta',
#    'Lega',
#    'AZZERARE',
#    'L',
#    'IVA',
#    'pane',
#    'pasta',
#    'latte',
#    'frutta',
#    'verdura',
#    'I',
#    'soldi',
#    'manca',
#    'volontà',
#    'farlo',
#    'Noi',
#    'insistiamo',
#    'mesi',
#    'speriamo',
#    'signori',
#    'No',
#    'smettano'],
#   ['Secondo',
#    'sindaco',
#    'Bologna',
#    '“',
#    'Il',
#    'fascismo',
#    'porte',
#    'Italia',
#    '”',
#    'Ma',
#    'bastaaaaa',
#    'Teniamoci',
#    'ben',
#    'stretta',
#    'Libertà',
#    'Democrazia',
#    'offriamo',
#    'Italiani',
#    'idee',
#    'soluzioni',
#    'insulti',
#    'Il',
#    '25',
#    'settembre',
#    'Lega',
#    'tornano',
#    'sicurezza',
#    'coraggio',
#    'lavoro'],
#   ['Occorre',
#    'tornare',
#    'SICUREZZA',
#    'difesa',
#    'Italia',
#    'punti',
#    'vista',
#    'Il',
#    '25',
#    'settembre',
#    'tornano',
#    'competenza',
#    'coraggio'],
#   ['Un',
#    '“',
#    'futuro',
#    'nero',
#    '”',
#    'Alla',
#    'sinistra',
#    'piacciono',
#    'sicurezza',
#    'controlli',
#    'certezza',
#    'pena',
#    'me',
#    'sì'],
#   ['Per',
#    'vuole',
#    '8.40',
#    '@rtl1025',
#    'Attendo',
#    'commenti',
#    '#nonstopnews',
#    '#25settembrevotolega'],
#   ['In', 'diretta', '@rtl1025'],
#   ['Per',
#    'Repubblica',
#    'problema',
#    'scafisti',
#    'clandestini',
#    'Salvini',
#    'Lampedusani',
#    'Italiani',
#    'chiedono',
#    'controlli',
#    'sicurezza',
#    'Il',
#    '25',
#    'settembre',
#    'scelta',
#    'solo',
#    'cambiare',
#    'può',
#    '#25settembrevotolega'],
#   ['La',
#    'proposta',
#    'Lega',
#    'chiara',
#    'azzerare',
#    "l'Iva",
#    'prodotti',
#    'latte',
#    'pane',
#    'pasta',
#    'frutta',
#    'verdura',
#    'Chi',
#    'riuscirà',
#    'dire',
#    'no',
#    'misura',
#    'buonsenso',
#    'aiutare',
#    'famiglie',
#    'periodo',
#    'difficile'],
#   ['Mario',
#    'Monti',
#    'difende',
#    'legge',
#    'Fornero',
#    'attacca',
#    'Lega',
#    'vuole',
#    'cancellare',
#    'Il',
#    '25',
#    'settembre',
#    'finalmente',
#    'Italiani',
#    'decidere'],
#   ['Secondo',
#    'PD',
#    'parliamo',
#    'troppo',
#    '“',
#    'sicurezza',
#    'immigrazione',
#    '”',
#    'post',
#    '“',
#    'aggressivi',
#    'violenti',
#    '”',
#    '1/2',
#    'Quindi',
#    'violenti',
#    'immigrati',
#    'aggrediscono',
#    'calci',
#    'pugni',
#    'sprangate',
#    'bottigliate',
#    'chiediamo',
#    'sicurezza',
#    'controlli',
#    'rispetto',
#    'regole',
#    'espulsioni',
#    'difesa',
#    'confini',
#    'Mah',
#    '…',
#    'Il',
#    '25',
#    'settembre',
#    'può',
#    'cambiare',
#    'finalmente',
#    'parola',
#    'torna',
#    'Voi',
#    '2/2'],
#   ['Dal',
#    '25',
#    'settembre',
#    'cambia',
#    'vergogna',
#    'stop',
#    'sbarchi',
#    'Lega',
#    'già',
#    'dimostrato',
#    'saper',
#    'fare',
#    'Ora',
#    'tocca',
#    'te',
#    '#25settembrevotoLega'],
#   ['“',
#    'Salvini',
#    'pieno',
#    'Madonne',
#    '…',
#    '”',
#    'Se',
#    'uniche',
#    'critiche',
#    'sinistra',
#    'riesce',
#    'muovermi',
#    'conferma',
#    'giusto',
#    'sbando'],
#   ['Salvini',
#    'Lega',
#    'governo',
#    'Per',
#    'compagno',
#    'De',
#    'Benedetti',
#    '“',
#    'orripilante',
#    '”',
#    'Addirittura',
#    'orripilanteeehhh',
#    '🤣',
#    'Il',
#    '25',
#    'settembre',
#    'decide',
#    'PD',
#    'finalmente',
#    'decidono',
#    'Italiani'],
#   ['Hotspot',
#    'Lampedusa',
#    'collasso',
#    'quasi',
#    '2mila',
#    'immigrati',
#    'presenti',
#    '300',
#    'posti',
#    'disponibili',
#    'E',
#    'sbarchi',
#    'proseguono',
#    '...',
#    'Dal',
#    '1',
#    '°',
#    'gennaio',
#    '26',
#    'luglio',
#    '2019',
#    'lavoro',
#    'Lega',
#    'ministero',
#    'interno',
#    'sbarcarono',
#    '3.589'],
#   ['Quest',
#    'anno',
#    'stesso',
#    'periodo',
#    '37.415',
#    'ingressi',
#    'clandestini',
#    'coste',
#    '10',
#    'volte',
#    'tanto',
#    'Il',
#    '4',
#    '5',
#    'agosto',
#    "sull'isola",
#    'controllare',
#    'persona',
#    'situazione',
#    'portare',
#    'soluzioni'],
#   ['E',
#    '25',
#    'settembre',
#    'cambia',
#    'vergogna',
#    'già',
#    'dimostrato',
#    'saper',
#    'fare',
#    'rischiando',
#    'persona',
#    'Ora',
#    'tocca',
#    'te',
#    '#25settembrevotoLega'],
#   ['#Salvini',
#    'Com',
#    'giusto',
#    'decidono',
#    'italiani',
#    'prende',
#    'voto',
#    'indica',
#    'governerà',
#    "l'Italia",
#    'prossimi',
#    'cinque',
#    'anni',
#    'La',
#    'squadra',
#    'centrodestra',
#    'compatta',
#    '#tg5',
#    '#25settembrevotoLega'],
#   ['#Salvini',
#    'A',
#    'sinistra',
#    'coalizione',
#    'Lavoro',
#    'riduzione',
#    'tasse',
#    'azzeramento',
#    'L.Fornero',
#    'guardiamo',
#    'temi',
#    'concreti',
#    'aspettano',
#    'mesi',
#    'difficili',
#    'dobbiamo',
#    'fare',
#    'promesse',
#    'irrealistiche',
#    '#tg5',
#    '#25settembrevotoLega'],
#   ['#Salvini',
#    'Lavoro',
#    'tasse',
#    'sicurezza',
#    'Azzerare',
#    'legge',
#    'Fornero',
#    'compiere',
#    '#quota41',
#    '#flattax',
#    'estesa',
#    'lavoratori',
#    'dipendenti',
#    'bloccare',
#    'sbarchi',
#    'migliaia',
#    'clandestini',
#    '#tg5',
#    '#25settembrevotoLega'],
#   ['#Salvini',
#    'Sicurezza',
#    'vuol',
#    'dire',
#    'fermare',
#    'sbarchi',
#    'migliaia',
#    'clandestini',
#    'arrivando',
#    'ore',
#    "L'ho",
#    'fatto',
#    'ministro',
#    'continuerò',
#    'farlo',
#    'quando',
#    'governo',
#    '#tg5',
#    '#25settembrevotoLega'],
#   ['Tg5',
#    'Lavoro',
#    'tasse',
#    'sicurezza',
#    'azzeramento',
#    'legge',
#    'Fornero',
#    'obiettivo',
#    '#quota41',
#    'estensione',
#    '#flattax',
#    'lavoratori',
#    'dipendenti',
#    'blocco',
#    'sbarchi',
#    'migliaia',
#    'clandestini',
#    'fatto',
#    'quando',
#    'ministro',
#    'rifarò',
#    'Noi',
#    'guardiamo',
#    'temi',
#    'concreti'],
#   ['Uniti', 'vince', 'Italia'],
#   ['Buon', 'viaggio', 'piccolo', 'Angelo', 'mondo', 'meritava'],
#   ['In',
#    'diretta',
#    'intervento',
#    'mattina',
#    'Radio',
#    '24',
#    'Seguitemi',
#    'fatemi',
#    'sapere',
#    'cosa',
#    'pensate',
#    '😊',
#    '#25settembrevotoLega'],
#   ['In',
#    'diretta',
#    "dall'assemblea",
#    'nazionale',
#    'Coldiretti',
#    'Un',
#    'piacere',
#    'essere',
#    'qui',
#    'state',
#    '😊',
#    '#25settembrevotoLega'],
#   ['Una',
#    'sinistra',
#    'divisa',
#    'disperata',
#    'qualche',
#    'servo',
#    'sciocco',
#    'qualche',
#    'redazione',
#    'passa',
#    'tempo',
#    'cercare',
#    'fascisti',
#    'russi',
#    'razzisti',
#    'Il',
#    '25',
#    'settembre',
#    'finalmente',
#    'cambia'],
#   ['Per',
#    'Ong',
#    'evitare',
#    'morti',
#    'mare',
#    'sbarcano',
#    'muoiono',
#    'combattere',
#    'scafisti',
#    'difendere',
#    'cittadini',
#    'lampedusani',
#    'italiani',
#    'immigrazione',
#    'clandestina',
#    '“',
#    'VERGOGNOSO',
#    '”',
#    'Il',
#    '25',
#    'settembre',
#    'cambia',
#    'rotta',
#    'sensi',
#    'La',
#    'Lega',
#    'pronta',
#    '#25settembrevotolega'],
#   ['Un',
#    'tragica',
#    'notizia',
#    'La',
#    'Lega',
#    'perde',
#    'giovane',
#    'papà',
#    'militante',
#    'consigliere',
#    'comunale',
#    'Pieve',
#    'Soligo',
#    'Treviso',
#    'Una',
#    'preghierà',
#    'ricordo',
#    'Andrea',
#    'condoglianze',
#    'famiglia',
#    'abbraccio',
#    'due',
#    'bimbi',
#    'Continueremo',
#    'battaglia',
#    'te'],
#   ['Latte',
#    '“',
#    'sintetico',
#    '”',
#    'senza',
#    'mucche',
#    'prodotto',
#    'laboratorio',
#    'Ma',
#    'basta'],
#   ['Più',
#    'ancora',
#    'smentita',
#    'prefetto',
#    'Gabrielli',
#    '“',
#    'notizia',
#    'priva',
#    'fondamento',
#    '”',
#    'querele',
#    '“',
#    'giornalisti',
#    '”',
#    'distratti',
#    'malafede',
#    'povero',
#    'Letta',
#    'risponde',
#    'grandissimo',
#    'Osho.Enrico',
#    'sereno',
#    '25',
#    'settembre',
#    'Italiani',
#    'scegliere',
#    'liberi',
#    'forti',
#    '#25settembrevotolega'],
#   ['Finalmente', 'dopo', 'tre', 'anni', 'BENTORNATA', 'PONTIDA'],
#   ['Che',
#    'strano',
#    '…',
#    'Secondo',
#    'caso',
#    'Amici',
#    'sinistra',
#    'fermarci',
#    'ce',
#    'mai',
#    'Il',
#    '25',
#    'settembre',
#    'conta',
#    'solo',
#    'voto',
#    '#25settembrevotoLega'],
#   ['Per',
#    'sinistra',
#    'Putin',
#    'spingere',
#    'barconi',
#    'pieni',
#    'clandestini',
#    'verso',
#    'Italia',
#    'Siamo',
#    'comiche',
#    'paura',
#    'perdere',
#    'poltrona',
#    'fa',
#    'brutti',
#    'scherzi',
#    'Spoiler',
#    'colpa',
#    'PD',
#    'Lamorgese'],
#   ['A',
#    'sinistra',
#    'paura',
#    'tremenda',
#    'perdere',
#    'poltrone',
#    'inventano',
#    'qualunque',
#    'Come',
#    'Lega',
#    'andiamo',
#    'avanti',
#    'testa',
#    'alta',
#    'parlando',
#    'Italia',
#    'italiani',
#    'giovani',
#    'ambiente',
#    'sviluppo',
#    'Pace',
#    'fiscale',
#    'riduzione',
#    'sbarchi',
#    'tasse',
#    'Enrico',
#    'serenissimo',
#    '#25settembrevotolega'],
#   ['Mentre',
#    'sinistra',
#    'gettano',
#    'fango',
#    'Lega',
#    'molla',
#    'temi',
#    'concreti',
#    'prossimo',
#    'Decreto',
#    'dimostrazione',
#    'elezioni',
#    'anticipate',
#    'bloccano',
#    'Paese',
#    'lavoriamo',
#    'confermare',
#    'sconti',
#    'carburanti',
#    'bollette',
#    'insistiamo',
#    'azzeramento',
#    'Iva',
#    'beni',
#    'prima',
#    'necessità'],
#   ['A',
#    'sinistra',
#    'paura',
#    'tremenda',
#    'perdere',
#    'poltrone',
#    'inventano',
#    'qualunque',
#    'Lega',
#    'va',
#    'avanti',
#    'testa',
#    'alta',
#    'parlando',
#    'Italia',
#    'italiani',
#    'giovani',
#    'futuro',
#    'ambiente',
#    'sviluppo',
#    'Pace',
#    'fiscale',
# ...
#    'Her',
#    'soul',
#    'rest',
#    'peace'],
#   ['Questa', 'sera', '#DrittoeRovescio'],
#   ['Il',
#    'Decreto',
#    'Aiuti',
#    '“',
#    'bloccato',
#    '”',
#    '@Mov5Stelle',
#    'Una',
#    'sonora',
#    'sciocchezza',
#    'Ieri',
#    'sera',
#    'spiegato',
#    'davvero',
#    'cose',
#    '#Tg2Post'],
#   ['“',
#    'Cambia',
#    'vento',
#    'no',
#    '…',
#    '”',
#    'Infuriano',
#    'polemiche',
#    'campagna',
#    'elettorale',
#    'lasciamo',
#    'distrarre',
#    'Oggi',
#    'vota',
#    'decidere',
#    'quali',
#    'progetti',
#    'destinare',
#    'fondo',
#    'accumulato',
#    'restituzioni',
#    'parlamentari',
#    'M5S',
#    'Sempre',
#    '#dallapartegiusta'],
#   ['In',
#    'diretta',
#    'Auditorium',
#    'Conciliazione',
#    'Roma',
#    'cuore',
#    'coraggio',
#    '#dallapartegiusta',
#    'Segui',
#    'diretta'],
#   ['Il',
#    'programma',
#    'idee',
#    'Paese',
#    'obiettivi',
#    'Segui',
#    'diretta',
#    'Roma',
#    '#dallapartegiusta'],
#   ['Gli', 'appuntamenti', 'domani', '⤵', '️'],
#   ['Per',
#    'programma',
#    'elettorale',
#    'malloppo',
#    'carta',
#    'consegnare',
#    'qualche',
#    'giorno',
#    'prima',
#    'elezioni',
#    'È',
#    'impegneremo',
#    'sempre',
#    'costi',
#    'quel',
#    'costi',
#    'solo',
#    'soltanto',
#    'bene',
#    'cittadini',
#    'Con',
#    'fianco',
#    'possiamo',
#    'portare',
#    "l'Italia",
#    '#dallapartegiusta'],
#   ['Direzione',
#    'Livorno',
#    'pausa',
#    'confrontato',
#    'cittadini',
#    'priorità',
#    'Governo',
#    "l'aumento",
#    'spese',
#    'militari',
#    'Non',
#    'crisi',
#    'famiglie',
#    'aziende',
#    'provvedimenti',
#    'impedire',
#    'mafiosi',
#    'uscire',
#    'carcere',
#    "C'è",
#    "un'Italia",
#    'chiede',
#    'altro',
#    '#dallapartegiusta'],
#   ['Cara',
#    'Liliana',
#    "l'intera",
#    'comunità',
#    '@Mov5Stelle',
#    'abbraccia',
#    'tanti',
#    'auguri',
#    'buon',
#    'compleanno'],
#   ['Livorno', 'passione', '#dallapartegiusta'],
#   ['Gli', 'appuntamenti', 'domani', '⤵', '️'],
#   ['Sta',
#    'girando',
#    'pericolosa',
#    'menzogna',
#    '@Mov5Stelle',
#    'Partiti',
#    'giornali',
#    'continuano',
#    'dire',
#    'bloccando',
#    'aiuti',
#    'famiglie',
#    'Non',
#    'così',
#    'Gli',
#    'aiuti',
#    'già',
#    'operativi',
#    'altre',
#    'forze',
#    'politiche',
#    'vogliono',
#    'tagliar',
#    'fuori',
#    '40mila',
#    'aziende',
#    'difficoltà',
#    'Non',
#    'permetteremo'],
#   ['Altri',
#    'miliardi',
#    'spese',
#    'militari',
#    'mentre',
#    'famiglie',
#    'imprese',
#    'ce',
#    'La',
#    'risposta',
#    'NO',
#    '#dallapartegiusta'],
#   ['Oggi', 'doppio', 'appuntamento', 'aspetto'],
#   ['Competenza',
#    'cuore',
#    'coraggio',
#    'Non',
#    'disposti',
#    'mollare',
#    'centimetro',
#    'valori',
#    'fare',
#    'bene',
#    'cittadini',
#    'Qui',
#    'intervista',
#    'poco',
#    'fa',
#    '#mezzorainpiù',
#    '#dallapartegiusta'],
#   ['Dopo',
#    '24',
#    'anni',
#    'Italia',
#    'campione',
#    'mondo',
#    '#pallavolo',
#    'Grazie',
#    'ragazzi',
#    '#ItaliaPolonia',
#    '#ItalVolley'],
#   ['Gli', 'appuntamenti', 'oggi', '📌', '#dallapartegiusta'],
#   ['In',
#    'bocca',
#    'lupo',
#    'studenti',
#    'docenti',
#    'personale',
#    'scolastico',
#    'prima',
#    'campanella',
#    'Oggi',
#    'ripropongo',
#    'intervista',
#    'amici',
#    'ScuolaZoo',
#    'parliamo',
#    'proposte',
#    'scuola',
#    'formazione',
#    'Leggerò',
#    'piacere',
#    'commenti'],
#   ['Un',
#    'momento',
#    'toccante',
#    'pomeriggio',
#    'Villa',
#    'Wolkonsky',
#    'sede',
#    'residenza',
#    '@EdLlewellynFCDO',
#    'doveroso',
#    'omaggio',
#    'intera',
#    'comunità',
#    '@Mov5Stelle',
#    'popolo',
#    'britannico',
#    'memoria',
#    'Sua',
#    'Maestà',
#    'Elisabetta',
#    'II'],
#   ['Ora', 'diretta', '@Radio1Rai'],
#   ['Ieri',
#    'sera',
#    'stato',
#    'ospite',
#    'Nicola',
#    'Porro',
#    '#QuartaRepubblica',
#    'Per',
#    'modo',
#    'seguire',
#    'ecco',
#    'video',
#    'intervista'],
#   ['Orgogliosi',
#    'essere',
#    "l'unica",
#    'forza',
#    'politica',
#    'restituisce',
#    'comunità',
#    'parte',
#    'indennità',
#    'ricevute',
#    'eletti',
#    'Venerdì',
#    'concluse',
#    'operazioni',
#    'voto',
#    'individuare',
#    'destinazione',
#    '2',
#    'milioni',
#    'euro',
#    'restituzioni',
#    'Qui',
#    'esito',
#    'voto',
#    '#dallapartegiusta'],
#   ['🤦\u200d♂', '️'],
#   ['Ora',
#    'Letta',
#    'chieda',
#    'scusa',
#    'altri',
#    'Grazie',
#    '@Mov5Stelle',
#    'Letta',
#    'chiamato',
#    'piccoli',
#    'calcoli',
#    'elettorali',
#    'oggi',
#    'stata',
#    'trovata',
#    'soluzione',
#    '40mila',
#    'imprese',
#    'edilizie',
#    'lavoratori',
#    'famiglie',
#    'stati',
#    'dimenticati',
#    '#dallapartegiusta'],
#   ['Ci', 'vediamo', 'domani', 'Puglia', '#dallapartegiusta'],
#   ['La', 'intervista', 'ieri', 'sera', '#cartabianca'],
#   ['Non', 'fate', 'ingannare', 'Scegliete', 'stare', '#dallapartegiusta'],
#   ['Via',
#    'libera',
#    'definitivo',
#    'Parlamento',
#    'europeo',
#    'direttiva',
#    '#salariominimo',
#    'Mentre',
#    'Italia',
#    'altri',
#    'partiti',
#    'pensano',
#    'alzare',
#    'stipendi',
#    'superdirigenti',
#    'Stato',
#    'continuiamo',
#    'batterci',
#    'salario',
#    'minimo',
#    'legale',
#    '9',
#    'euro',
#    "l'ora",
#    'Basta',
#    'paghe',
#    'fame',
#    '#dallapartegiusta'],
#   ['La',
#    'determinazione',
#    'paga',
#    'Governo',
#    'tornato',
#    'passi',
#    'appena',
#    'annunciato',
#    'voler',
#    'cancellare',
#    'norma',
#    'alza',
#    'megastipendi',
#    'dirigenti',
#    'Stato',
#    'Meglio',
#    'tardi',
#    'mai',
#    'Vi',
#    'teniamo',
#    'aggiornati'],
#   ['Eppure', 'votato', 'Enrico', '🤔', 'Un', 'bel', 'tacer', 'mai', 'scritto'],
#   ['Ritornare',
#    'terra',
#    'Puglia',
#    'sempre',
#    'emozionante',
#    'Grazie',
#    'Brindisi',
#    'affetto',
#    'mattina',
#    '#dallapartegiusta'],
#   ['Gli', 'appuntamenti', 'domani', '⤵', '️', '#DallaParteGiusta'],
#   ['Oggi',
#    'tantissimi',
#    'ribadito',
#    "c'è",
#    'bisogno',
#    '@Mov5Stelle',
#    'Paese',
#    'Contro',
#    'ingiustizie',
#    "un'Italia",
#    'cambia',
#    'ascoltando',
#    'voce',
#    'Grazie',
#    'Bisceglie',
#    'Trani',
#    'Barletta',
#    'Andria',
#    'Ci',
#    'vediamo',
#    'fra',
#    'poco',
#    'Foggia',
#    'Stiamo',
#    'insieme',
#    '#dallapartegiusta'],
#   ['In', 'diretta', 'Foggia', '#DallaParteGiusta'],
#   ['Questo',
#    'Paese',
#    'sottosopra',
#    'Senza',
#    'dimenticato',
#    '40',
#    'mila',
#    'imprese',
#    'edilizie',
#    'rischio',
#    'chiusura',
#    'alzato',
#    'invece',
#    'superstipendi',
#    'dirigenti',
#    'Stato',
#    'Ecco',
#    "c'è",
#    'bisogno',
#    '@Mov5Stelle',
#    'Italia',
#    'oggi',
#    'mai',
#    '#dallapartegiusta'],
#   ['Questa',
#    'campagna',
#    'elettorale',
#    'possibile',
#    'soltanto',
#    'grazie',
#    'Scegliete',
#    'stare',
#    '#dallapartegiusta',
#    'ancora',
#    'fatto',
#    'potete',
#    'contribuire',
#    'donazione',
#    'qui',
#    '⤵',
#    '️'],
#   ['La',
#    'grande',
#    'sofferenza',
#    'essere',
#    'soli',
#    'Don',
#    'Puglisi',
#    'sfidato',
#    'mafia',
#    'stato',
#    'ucciso',
#    '29',
#    'anni',
#    'fa',
#    'Ci',
#    'insegnato',
#    'combattere',
#    'criminalità',
#    'necessario',
#    'battersi',
#    'affinché',
#    'nessuno',
#    'dimenticato',
#    'resti',
#    'indietro',
#    'Non',
#    'lasciamo',
#    'cadere',
#    'monito'],
#   ['Ciao',
#    'Bari',
#    'grazie',
#    'calore',
#    'mattina',
#    'Ora',
#    'riparte',
#    'direzione',
#    'Sicilia',
#    'Vi',
#    'aspetto',
#    'sera',
#    'Catania',
#    'Piazza',
#    'Palestro',
#    '#dallapartegiusta'],
#   ['Qui', 'seguito', 'appuntamenti', 'domani', 'aspetto', '#dallapartegiusta'],
#   ['Catania',
#    'so',
#    'dire',
#    'Così',
#    'cambiamo',
#    'Qui',
#    'Sicilia',
#    "l'onda",
#    'iniziata',
#    'qui',
#    "l'onda",
#    'riparte',
#    '#dallapartegiusta'],
#   ['...',
#    'fine',
#    'serata',
#    'pausa',
#    'cuore',
#    'Catania',
#    '@NuccioDiPaola',
#    'sempre',
#    '#dallapartegiusta'],
#   ['Ci',
#    'stringiamo',
#    'forte',
#    'marchigiani',
#    'ore',
#    'drammatiche',
#    'Pronti',
#    'fare',
#    'possibile',
#    'aiutare',
#    'famiglie',
#    'territori',
#    'colpiti'],
#   ['Una',
#    'mattinata',
#    'piena',
#    'entusiasmo',
#    'oggi',
#    'Messina',
#    'Grazie',
#    '#dallapartegiusta'],
#   ['La',
#    'questione',
#    'davvero',
#    'molto',
#    'seria',
#    'Meloni',
#    'Salvini',
#    'devono',
#    'chiarire'],
#   ['Tiberio',
#    'Angela',
#    'ribellano',
#    'mafie',
#    'soli',
#    '@Mov5Stelle',
#    'fianco',
#    'Oggi',
#    'Reggio',
#    'Calabria',
#    'Federico',
#    'Cafiero',
#    'de',
#    'Raho',
#    'ribadito',
#    'impegno',
#    'legalità',
#    'Nessun',
#    'passo',
#    'indietro',
#    'parola',
#    '#dallapartegiusta'],
#   ['Domani', 'ancora', 'Sicilia', 'ecco', '⤵', '️', '#dallapartegiusta'],
#   ['Siracusa',
#    'Marina',
#    'Ragusa',
#    'abbraccerei',
#    'Il',
#    'calore',
#    'conferma',
#    'voglia',
#    'stare',
#    '#dallapartegiusta'],
#   ['#DallaParteGiusta', '@NuccioDiPaola', 'diretta', 'Gela'],
#   ['Splendida',
#    'serata',
#    'Gela',
#    'Avanti',
#    'insieme',
#    'sempre',
#    '#dallapartegiusta'],
#   ['Oggi',
#    'Enna',
#    'poi',
#    'Caltanissetta',
#    'Roberto',
#    'Scarpinato',
#    'vero',
#    'proprio',
#    'simbolo',
#    'lotta',
#    'mafia',
#    'candidato',
#    'Parlamento',
#    'mentre',
#    'centrodestra',
#    'Sicilia',
#    'candida',
#    'Renato',
#    'Schifani',
#    'imputato',
#    'processo',
#    'Montante',
#    'Orgogliosi',
#    'stare',
#    '#dallapartegiusta'],
#   ['Ognuno',
#    'sceglie',
#    'simboli',
#    'battaglie',
#    'La',
#    'strada',
#    'chiama',
#    'legalità',
#    'fianco',
#    "c'è",
#    'Roberto',
#    'Scarpinato',
#    'ex',
#    'magistrato',
#    'pool',
#    'antimafia',
#    'Falcone',
#    'Borsellino',
#    'La',
#    'mafia',
#    'combattiamola',
#    'ogni',
#    'giorno',
#    'ogni',
#    'città',
#    'quartiere',
#    'quartiere',
#    '#dallapartegiusta'],
#   ['Ancora',
#    'onda',
#    'affetto',
#    'calore',
#    'Sicilia',
#    'Ancora',
#    'entusiasmo',
#    'tantissime',
#    'amiche',
#    'amici',
#    'Agrigento',
#    'Trapani',
#    'passo',
#    'dopo',
#    'passo',
#    'danno',
#    'grandissima',
#    'forza',
#    'Ci',
#    'vediamo',
#    'fra',
#    'poco',
#    'Palermo',
#    'Piazza',
#    'Verdi',
#    '22',
#    'Vi',
#    'aspetto',
#    '#dallapartegiusta'],
#   ['In', 'diretta', 'Palermo', '#dallapartegiusta'],
#   ['Ieri',
#    'sera',
#    'collegamento',
#    'Palermo',
#    'stato',
#    'ospite',
#    '@tpi',
#    'Fest',
#    'Bologna',
#    'Qui',
#    'seguito',
#    'intervista'],
#   ['Domani',
#    'prima',
#    'Genova',
#    'poi',
#    'Milano',
#    'ecco',
#    'appuntamenti',
#    '⤵',
#    '️',
#    '#dallapartegiusta'],
#   ['Grazie',
#    'Movimento',
#    '5',
#    'Stelle',
#    '2',
#    'anni',
#    'riusciamo',
#    'lavorare',
#    'avere',
#    'reddito',
#    'dignitoso',
#    'mangiare',
#    'pizza',
#    'sera',
#    'I',
#    'lavoratori',
#    'settore',
#    'edile',
#    'spiegato',
#    'due',
#    'anni',
#    'fa',
#    'prima',
#    'Superbonus',
#    '110',
#    "c'erano",
#    'prospettive',
#    'lavoro'],
#   ['Siamo',
#    'orgogliosi',
#    'aver',
#    'dato',
#    'spinta',
#    'economica',
#    'segno',
#    'sostenibilità',
#    'ambientale',
#    'intero',
#    'comparto',
#    'Al',
#    'fianco',
#    'lavora',
#    'sempre',
#    '#dallapartegiusta'],
#   ['Oggi', 'tv', 'ecco', '⤵', '️', '#ore14', '#staseraitalia'],
#   ['A',
#    'Genova',
#    'approfitto',
#    'rapido',
#    'saluto',
#    'Beppe',
#    'Con',
#    'cuore',
#    'coraggio',
#    'sempre',
#    '#dallapartegiusta'],
#   ['Poco',
#    'fa',
#    'stato',
#    'ospite',
#    'trasmissione',
#    '#Ore14',
#    'Vi',
#    'ripropongo',
#    'qui',
#    'intervista',
#    '#dallapartegiusta'],
#   ['La', 'intervista', 'poco', 'fa', '#StaseraItalia', '#DallaParteGiusta'],
#   ['Venerdì',
#    '23',
#    'settembre',
#    '18',
#    'aspetto',
#    'Piazza',
#    'Santi',
#    'Apostoli',
#    'Roma',
#    'chiusura',
#    'campagna',
#    'elettorale',
#    'Non',
#    'mancate',
#    '#dallapartegiusta'],
#   ['Questa', 'mattina', 'intervista', '@Agenzia_Ansa', '#dallapartegiusta'],
#   ['Questa', 'sera', 'tv', '⤵', '️', '#DallaParteGiusta'],
#   ['A',
#    'Silvana',
#    'Sciarra',
#    'nuova',
#    'Presidente',
#    'Corte',
#    'Costituzionale',
#    'auguri',
#    'buon',
#    'lavoro',
#    '@Mov5Stelle',
#    'La',
#    'riconosciuta',
#    'competenza',
#    'costituisce',
#    'sicura',
#    'garanzia',
#    'esercizio',
#    'ruolo',
#    'istituzionale',
#    'fondamentale',
#    'equilibri',
#    'Paese'],
#   ['Oggi', 'amici', '@Skuolanet'],
#   ['Sandro',
#    'clan',
#    'prepotenza',
#    'camorra',
#    'bisogna',
#    'essere',
#    'uniti',
#    'esistono',
#    'steccati',
#    'simboli',
#    'partiti',
#    'dividerci',
#    'Siamo',
#    'fianco'],
#   ['Ci', 'vediamo', 'domani', 'Campania', 'Sempre', '#dallapartegiusta'],
#   ['La', 'intervista', 'sera', '#dimartedi', '#DallaParteGiusta'],
#   ['Fra', 'poco', '@agorarai'],
#   ['Questa', 'mattina', 'studi', '@agorarai', 'ecco', 'intervista'],
#   ['Non',
#    'fatevi',
#    'ingannare',
#    'Ecco',
#    'vero',
#    'volto',
#    'Meloni',
#    'co',
#    'povertà',
#    'Disprezzano',
#    'nulla',
#    'trova',
#    'momento',
#    'difficile',
#    'vogliono',
#    'togliergli'],
#   ['Per',
#    'povertà',
#    'colpa',
#    'può',
#    'capitare',
#    'momento',
#    'così',
#    'difficile',
#    'perdere',
#    'lavoro',
#    'perdere',
#    'strada',
#    'costruita',
#    'fatica',
#    'Tutti',
#    'devono',
#    'avere',
#    'certezza',
#    'rimanere',
#    'soli',
#    '#dallapartegiusta'],
#   ['Gli', 'appuntamenti', 'tv', 'oggi', '⤵', '️'],
#   ['Napoli',
#    'sempre',
#    'abbraccio',
#    'entusiasmo',
#    'calore',
#    'Grazie',
#    'amici',
#    'amiche',
#    'mattinata',
#    'continuiamo',
#    'insieme',
#    '#dallapartegiusta'],
#   ['In',
#    'collegamento',
#    'Napoli',
#    'stato',
#    'ospite',
#    '#Tagadà',
#    'La7',
#    'Vi',
#    'ripropongo',
#    'qui',
#    'intervista'],
#   ['Proprio', 'così', '#dallapartegiusta'],
#   ['Con',
#    '@SergioCosta_Gen',
#    'raccontiamo',
#    'cosa',
#    'fatto',
#    '#Bagnoli',
#    'Nel',
#    '2018',
#    'rimboccati',
#    'maniche',
#    'sbloccato',
#    'opere',
#    'bonifica',
#    'necessarie',
#    'dopo',
#    'trent',
#    'anni',
#    'inerzia',
#    'politica',
#    'Il',
#    '@Mov5Stelle',
#    'mette',
#    'sempre',
#    'sempre',
#    '#dallapartegiusta'],
#   ['In', 'diretta', 'Giugliano', 'Campania', '#dallapartegiusta'],
#   ['Acerra',
#    'Caserta',
#    'Giugliano',
#    '…',
#    'grazie',
#    'accoglienza',
#    'oggi',
#    'Tutti',
#    '#dallapartegiusta'],
#   ['Nelle', 'prossime', 'ore', 'tv', '📌', '#dallapartegiusta'],
#   ['Questa',
#    'mattina',
#    '@Ariachetira',
#    'detto',
#    'alcune',
#    'cose',
#    'importanti',
#    'vorrei',
#    'condividere',
#    'qui',
#    'Ecco',
#    'intervista',
#    '#DallaParteGiusta'],
#   ['Gli', 'appuntamenti', 'sera', 'tv', '📺', '#dallapartegiusta'],
#   ['Davvero',
#    '@Mov5Stelle',
#    'occupato',
#    'Nord',
#    'Paese',
#    'I',
#    'fatti',
#    'raccontano',
#    'altra',
#    'storia',
#    'Qui',
#    'spiego'],
#   ['Giorgia',
#    'combattuto',
#    'così',
#    'bene',
#    'povertà',
#    'ultima',
#    'volta',
#    'stata',
#    'Governo',
#    'prima',
#    'Berlusconi',
#    'Salvini',
#    'poi',
#    'stampella',
#    'tecnico',
#    'persone',
#    'povertà',
#    'assoluta',
#    'passate',
#    '2,1',
#    '3,5',
#    'milioni',
#    'Non',
#    'credi',
#    'aver',
#    'fatto',
#    'già',
#    'abbastanza',
#    'danni'],
#   ['La', 'intervista', 'oggi', 'Pomeriggio', 'Cinque'],
#   ['La', 'intervista', 'Tg1', '#dallapartegiusta'],
#   ['Cosa', 'resterà', 'Governo', 'Migliori', 'Ditemelo', 'so'],
#   ['Ieri',
#    'sera',
#    'stato',
#    'ospite',
#    'Bruno',
#    'Vespa',
#    '#PortaaPorta',
#    'Ho',
#    'modo',
#    'parlare',
#    'programma',
#    'proposte',
#    'governo',
#    'Paese',
#    'Qui',
#    'intervista',
#    '#dallapartegiusta'],
#   ['Ci',
#    'Ci',
#    'vediamo',
#    'sera',
#    'Piazza',
#    'Santi',
#    'Apostoli',
#    'Roma',
#    'chiudere',
#    'campagna',
#    'elettorale',
#    'insieme',
#    'Vi',
#    'aspetto',
#    '18',
#    '#dallapartegiusta'],
#   ['Domenica', '25', 'settembre', 'può', 'sbagliare', 'Ecco', 'vota'],
#   ['Vi', 'aspetto', '#DallaParteGiusta'],
#   ['Ci',
#    'detto',
#    'morti',
#    'A',
#    'me',
#    'sembra',
#    'ottima',
#    'salute',
#    '#dallapartegiusta'],
#   ['In',
#    'diretta',
#    'Piazza',
#    'Santi',
#    'Apostoli',
#    'Roma',
#    '#dallapartegiusta'],
#   ['Un', 'abbraccio', 'grande', 'così', '#dallapartegiusta'],
#   ['È',
#    'stata',
#    'campagna',
#    'elettorale',
#    'molto',
#    'emozionante',
#    'Non',
#    'smettiamo',
#    'mai',
#    'lottare',
#    "un'Italia",
#    'migliore',
#    '#dallapartegiusta']]}

# %%
with open('your_file.txt', 'w') as f:
    for line in [" ".join(tweet) for tweet in tokenized_data["meloni"]]:
        f.write(f"{line}\n")

# %% [markdown]
# ### Lemmatizer

# %%
#from nltk.stem import WordNetLemmatizer

#nltk.download('wordnet')
#nltk.download('omw-1.4')

# %%
#lemma = WordNetLemmatizer()

#lemmatize = lambda tokenized_text, lemmatizer: [lemmatizer.lemmatize(word.lower()) for word in tokenized_text] 

#lemmatized_data = {politician: [lemmatize(tweet, WordNetLemmatizer()) for tweet in tokenized_data[politician]] for politician in POLITICIANS}

# %%
lemmatizer_list = pd.read_csv("https://raw.githubusercontent.com/michmech/lemmatization-lists/master/lemmatization-it.txt", sep="\t", header=None)
lemmatizer_dict = dict((rows[1],rows[0]) for _, rows in lemmatizer_list.iterrows())

# %%
def dict_check(key):
    if key in lemmatizer_dict: 
        return lemmatizer_dict[key]
    else:
        return key

# %%
lemmatize = lambda tokenized_text: [dict_check(word.lower()) for word in tokenized_text] 

lemmatized_data = {politician: [lemmatize(tweet) for tweet in tokenized_data[politician]] for politician in POLITICIANS}

# %%
cleaned_tweet = list()

for tweet, lemmatized_tweet in zip(filtered_data["bonino"], lemmatized_data["bonino"]):
    cleaned_tweet.append([tweet, lemmatized_tweet])

pd.DataFrame(cleaned_tweet).to_csv("TBD/test_lemma.csv")

# %% [markdown]
# ### Stemmer

# %%
class OurStemmer():

    def __init__(self, custom_tokens: list[str]):
        self.custom_tokens = custom_tokens
        self.stemmer = SnowballStemmer("italian")

    def stem(self, token):
        if token in self.custom_tokens:
            return token
        return self.stemmer.stem(token)

# %%
our_stemmer = OurStemmer(["Draghi", "Meloni", "Pnrr"])
default_stemmer = SnowballStemmer("italian")

test_tweet = "Il voto per Meloni è l'unica arma che abbiamo per cambiare le cose. Draghi ha costruito male il Pnrr e deve essere modificato."

print("Tweet: ",[word for word in test_tweet.split(" ")])
print("Our Stemmer: ", [our_stemmer.stem(word) for word in test_tweet.split(" ")])
print("Snowball Stemmer: ", [default_stemmer.stem(word) for word in test_tweet.split(" ")])
# Out:
# Tweet:  ['Il', 'voto', 'per', 'Meloni', 'è', "l'unica", 'arma', 'che', 'abbiamo', 'per', 'cambiare', 'le', 'cose.', 'Draghi', 'ha', 'costruito', 'male', 'il', 'Pnrr', 'e', 'deve', 'essere', 'modificato.']
# Our Stemmer:  ['il', 'vot', 'per', 'Meloni', 'è', "l'unic", 'arma', 'che', 'abbiam', 'per', 'camb', 'le', 'cose.', 'Draghi', 'ha', 'costru', 'mal', 'il', 'Pnrr', 'e', 'dev', 'esser', 'modificato.']
# Snowball Stemmer:  ['il', 'vot', 'per', 'melon', 'è', "l'unic", 'arma', 'che', 'abbiam', 'per', 'camb', 'le', 'cose.', 'drag', 'ha', 'costru', 'mal', 'il', 'pnrr', 'e', 'dev', 'esser', 'modificato.']

# %%
stem = lambda tokenized_text, stemmer: [stemmer.stem(word) for word in tokenized_text] 

stemmed_data = {politician: [stem(tweet, OurStemmer(open("words.txt", "r").read().split('\n'))) for tweet in tokenized_data[politician]] for politician in POLITICIANS}

# %%
with open('your_file.txt', 'w') as f:
    for line in [" ".join(tweet) for tweet in stemmed_data["conte"]]:
        f.write(f"{line}\n")

# %% [markdown]
# ### Tfidf

# %%
test_docs = [' '.join(tweet) for tweet in stemmed_data["salvini"]]

#   tf–idf
tfidf_vectorizer = TfidfVectorizer()
X_tfidf = tfidf_vectorizer.fit_transform(test_docs)
# Convert to standard matrix
X_tfidf.toarray()


# get the first vector out (for the first document) 
first_vector_tfidf=X_tfidf[7] 
 
# place tf-idf values in a pandas data frame 
df = pd.DataFrame(first_vector_tfidf.T.todense()
                    , index=tfidf_vectorizer.get_feature_names()
                    , columns=["tfidf"]) 

df.sort_values(by=["tfidf"], ascending=False)
# Out:
# /Users/robertostaino/Desktop/Università/Text Mining and Sentiment Analysis/how-politician-change-their-mind/.venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                tfidf
# previst     0.424015
# candid      0.335716
# non         0.262324
# vot         0.245370
# sdopp       0.221617
# ...              ...
# esattorial  0.000000
# esaur       0.000000
# esclus      0.000000
# esclusion   0.000000
# 𝑣𝑖𝑡𝑎        0.000000
#
# [3115 rows x 1 columns]

# %%
# Standardization of datasets is a common requirement for many machine learning estimators implemented in scikit-learn; they might behave badly if the individual features do not more or less look like standard normally distributed data: Gaussian with zero mean and unit variance.

scaler = StandardScaler()
stand_X_tfidf = scaler.fit_transform(X_tfidf.toarray())
stand_X_tfidf
# Out:
# array([[-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443],
#        [-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443],
#        [-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443],
#        ...,
#        [-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443],
#        [-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443],
#        [-0.04878761, -0.10189967, -0.03454443, ..., -0.03454443,
#         -0.03454443, -0.03454443]])

# %%
pca = PCA().fit(stand_X_tfidf)
nc  = list(range(1,1+len(pca.explained_variance_ratio_)))
ev  = np.cumsum(pca.explained_variance_ratio_)

#print(f'number of components: {nc}')
#print(f'cumulative explained variance: {ev}')

plt.plot(nc, ev)
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
# Keep only the first 2 components
pca = PCA(n_components = 2)

# Fit PCA and transform the data in the new coordinates
X_pca = pca.fit_transform(stand_X_tfidf)

# term-document matrix in the new coordinates
X_pca = pd.DataFrame(data = X_pca, columns = ['pc1', 'pc2'])
X_pca
# Out:
#           pc1       pc2
# 0   -0.051636 -0.016901
# 1   -0.230400 -0.202783
# 2   -0.153004 -0.106288
# 3   -0.130538 -0.083338
# 4    1.645739 -0.112297
# ..        ...       ...
# 834 -0.207215 -0.164498
# 835 -0.209397 -0.135796
# 836 -0.237920 -0.194195
# 837 -0.150171 -0.107391
# 838 -0.177884 -0.143840
#
# [839 rows x 2 columns]

# %%
test_docs
# Out:
# ['#domanivotoleg',
#  'e sorpres dev esser sincer commoss cerc nascond po figl Federico molt riserv me propr aspett p s doman vot prim volt dett “ fors ” scegl Lega 🥲 2/2',
#  'ier durant #maratonasalvin liv canal social dett dietr quint “ c contrib sorpres te ” 1/2',
#  'la interv qualc giorn fa ve ripropong #domanivotoleg']

# %%
X_pca.plot(kind = 'scatter', x = 'pc1', y = 'pc2', color = ['red'])
plt.show()

# %%
cleaned_tweet = list()

for tweet in filtered_data["bonino"]:
    cleaned_tweet.append([tweet, tokenize(tweet)])

pd.DataFrame(cleaned_tweet).to_csv("TBD/test.csv")

# %% [markdown]
# ## IS SPACY USEFUL?

# %%
# Punctuation cleaning

nlp = spacy.load("it_core_news_lg")

corpus = dict()
for politician in POLITICIANS:
    corpus[politician] = []
    for tweet in filtered_data[politician]:
        for sentence in nlp(tweet).sents:
            # TODO add readibility/ do better
            sentence_text_w_placeholder = re.sub('\+Europa', 'SPECIFICPOLITICALPARTYPLACEHOLDER', sentence.text, flags=re.IGNORECASE)
            cleaned_sentence_text = "".join([x for x in sentence_text_w_placeholder if x not in punctuation and x not in digits])
            corpus[politician].append(re.sub('SPECIFICPOLITICALPARTYPLACEHOLDER', '+Europa', cleaned_sentence_text))

# %%
# Tokenization, Lemmatization, StopWords Remover

tokenize = lambda text: [x.lemma_.lower() for x in nlp(text) if x.pos_ in ['NOUN', 'PROPN']]
vectorizer = CountVectorizer(tokenizer=tokenize)
X = vectorizer.fit_transform(corpus["salvini"])
Xa = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
# Out:
# /Users/teo/Documents/unimi/how-politician-change-their-mind/.venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
Xa.sum().sort_values(ascending=False)
# Out:
# settembrevotolega    197
# lega                 181
# settembre            148
# italiano              96
# italia                90
#                     ...
# intelligenza           1
# insicurezza            1
# insetto                1
# insegnamento           1
# 🥲                      1
# Length: 1896, dtype: int64

# %%
tokenize = lambda text: [x.lemma_.lower() for x in nlp(text) if x.pos_ in ['NOUN', 'PROPN']]
vectorizer = CountVectorizer(tokenizer=tokenize)
X = vectorizer.fit_transform(corpus["calenda"])
Xa = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
# Out:
# /Users/teo/Documents/unimi/how-politician-change-their-mind/.venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
Xa.sum().sort_values(ascending=False)
# Out:
# drago       137
# paese       123
# italia      106
# pd          106
# governo     103
#            ...
# opinione      1
# opificio      1
# distanza      1
# operaio       1
# a             1
# Length: 2408, dtype: int64

# %%
tokenize = lambda text: [x.lemma_.lower() for x in nlp(text) if x.pos_ in ['NOUN', 'PROPN']]
vectorizer = CountVectorizer(tokenizer=tokenize)
X = vectorizer.fit_transform(corpus["renzi"])
Xa = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
Xa.sum().sort_values(ascending=False)
# Out:
# /Users/teo/Documents/unimi/how-politician-change-their-mind/.venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# secondo      17
# drago        16
# campagna     16
# settembre    14
# melone       14
#              ..
# giugno        1
# giovedì       1
# giovane       1
# giorgia       1
# ♂             1
# Length: 542, dtype: int64

# %%
tokenize = lambda text: [x.lemma_.lower() for x in nlp(text) if x.pos_ in ['NOUN', 'PROPN']]
vectorizer = CountVectorizer(tokenizer=tokenize)
X = vectorizer.fit_transform(corpus["conte"])
Xa = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
Xa.sum().sort_values(ascending=False)
# Out:
# /Users/teo/Documents/unimi/how-politician-change-their-mind/.venv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# sera          58
# intervista    58
# movstelle     56
# grazie        40
# diretta       32
#               ..
# lisola         2
# linteresse     2
# linea          2
# limpegno       2
# 📺              2
# Length: 672, dtype: int64

# %%
def clean_data(corpus: list):
    # TODO
    return corpus

# %% [markdown]
# ## Clean data

# %%
out_data = clean_data(input_data)
